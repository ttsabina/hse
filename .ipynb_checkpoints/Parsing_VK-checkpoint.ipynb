# %% [markdown]
# # Часть 1: Парсим VK, продолжаем работать с API

# %% [markdown]
# - Коротко что это и зачем
# - VK developers, API
# - Создаём свое приложение, получаем токен
# - Первый запрос, выкачиваем свою стенку
# - Список групп для парсинга, что хотим скачать и как
# #Скачиваем всех людей, состоящих в группах
# #Получаем соцдем
# #Получаем стенки и записи

# %% [markdown]
# # Подготовка
#
# Нельзя просто взять и нажать на одну кнопку, чтобы получить все данные из Вконтакте.
#
# <img align="center" src="pictures/csv.png" height="600" width="600">
#
# Поэтому нам нужен API.
#
# С помощью API Вконтакте можно получить большой объем данных без серьёзных ограничений. Например, Facebook по своему API отдаст вам информацию только о тех людях, которые установили ваше приложение, API Одноклассников потребует написать им письмо с объяснением того, зачем это вам понадобились их данные, а API Вконтакте отдаст вам всё практически задаром. Единственное, что он попросит — это не обращаться к сайту очень часто.
#
# Ознакомиться со способами взаимодействия с Вконтакте можно по [ссылке](https://dev.vk.com/ru/guide) в специальной документации разработчика. Понятная документация — лучший друг для парсера.
#
#
# Для того, чтобы получить доступ к выгрузке данных, нужно пройти ряд бюрократических процедур.
#
# Первая такая процедура заключается в создании своего приложения. Для этого переходим по [ссылке](https://dev.vk.com/ru/mini-apps/management/creating-new-apps) и проходимся по необходимым процедурам:
#
# <img align="center" src="pictures/app_creation_1.jpg" height="600" width="600">
#
# После подтверждения своей личности по номеру телефона, попадаем на страницу свежесозданного приложения
# <img align="center" src="pictures/app_creation_2.jpg" height="600" width="600">
#
# Слева нам будем доступна вкладка с настройками, перейдя в неё мы увидим все необходимые нам для работы с приложением параметры
# <img align="center" src="pictures/app_creation_3.jpg" height="600" width="600">
#
#
# Для работы с частью методов API этого вполне достаточно (обычно в заголовке такого метода стоит соответствующая пометка). Для части методов, используемых нами, может понадобиться ключ доступа.
#
# Для того, чтобы получить его, необходимо сделать ещё пару странных манипуляций:
#
# Переходим по ссылке вида (на месте звездочек должен стоять ID созданного вами приложения):
#
# > https://oauth.vk.com/authorize?client_id=**********&scope=14&redirect_uri=https://oauth.vk.com/blank.html&display=page&v=5.103&response_type=token
#
# <img align="center" src="pictures/app_creation_4.jpg" height="600" width="600">
#
# Нажав кнопку "Продолжить как **пользователь**" будет сформирована ссылка с токеном следующего вида:
# > https://oauth.vk.com/blank.html#access_token=vk1.a.token&expires_in=86400&user_id=*******
#
# Первый набор символов, который следует за access_token= и начинается с **_vk1_** является токеном, т.е. ключом доступа. Это важные данные для подключения к API и получения данных.
#
# Вторая цифра (expires_in=) время работы маркера доступа в секундах (одни сутки). По истечению суток нужно будет получить новый маркер доступа. Последняя цифра (user_id=) ваш ID Вконтакте.
#
# Нам в дальнейшем понадобится токен. Для удобства сохраним его в отдельном файле **token.txt** в той же директории что и файл с кодом. В целях безопасности ваших данных не стоит нигде светить токенами и тем более выкладывать их в открытый доступ.
#
# Также обратите внимание на странный параметр scope=14 внутри ссылки с токеном. Эта загадочная цифра ничто иное, как права доступа к социальной сети. Подробнее познакомиться с взаимно-однозначным соответствием между числами и правами можно в документации. Например, если мы хотим получить доступ к друзьям, фото и аудио, мы подставим в scope цифру 2+4+8=14.

# %% [markdown]
# # Первые шаги

# %%
# Загружаем необходимые библиотеки

import datetime                  # Пакет для работы с временными форматами
import pickle                    # Пакет для подгрузки данных специфического для питона формата
import requests                  # Пакет для скачки данных из этих ваших интернетов
import pandas as pd              # Пакет для работы с таблицами
import numpy as np               # Пакет для работы с векторами и матрицами
import matplotlib.pyplot as plt  # Пакет для строительства графиков
import time            # Пакет для работы со временем. Например, помогает ставить заглушки 
                       # time.sleep(секунды), необходимые для того что ВК не банил нащего
                       # сборщика данных из-за слишком частых запросов
        
# Пакет для красивых циклов. При желании его можно отключить. Тогда из всех циклов придётся 
# удалять команду tqdm_notebook.
from tqdm import tqdm_notebook   # подробнее: https://github.com/tqdm/tqdm

# %%
# мой номер странички
my_user_id = 21519895
# версия используемого API
version = '5.103' 
# подгружаем токен
with open('token.txt') as f:
    token = f.read()

# %% [markdown]
# Чтобы задать вопрос API вконтакте, нужно сформировать ссылку следующего вида:
#
# > https://api.vk.com/method/METHOD_NAME?PARAMETERS&access_token=ACCESS_TOKEN&v=API_VERSION
#
# > https://название_api/используемый_метод?параметры_метода&другие_опции&ключ_доступа&версия_API
#
# В ссылку сначала встраивается метод, с помощью которого мы осуществляем запрос и какие-то параметры для этого метода. Список всех существующих методов и параметров можно изучить, конечно же, в документации.
#
# Попробуем узнать своё имя. Метод `users.get` возвращает расширенную информацию о пользователе. Параметр `user_ids` отвечает за `id` пользователей, информацию о которых нам хотелось бы вытащить.

# %%
url = "https://api.vk.com/method/users.get?user_ids={user_id}&access_token={token}&v={version}"
url = url.format(user_id=my_user_id, token=token, version=version)

# %%
response = requests.get(url) 
response
# Out:
# <Response [200]>

# %% [markdown]
# Ура! Благословенный 200-ответ! Мы получили его в удобном json формате, который python воспринимает как словарик.

# %%
name = response.json()
name
# Out:
# {'response': [{'id': 21519895,
#    'first_name': 'Ксения',
#    'last_name': 'Орлова',
#    'can_access_closed': True,
#    'is_closed': False}]}

# %% [markdown]
# Со словарями очень удобно работать, поэтому выведем первый и единственный элемент из списка response

# %%
name['response'][0]

# %% [markdown]
# Оформим всё, что мы сделали выше в виде удобной функции, которая будет пригодна для любых методов и параметров.

# %%
def vkDownload(method, parameters, token=token, version=version):
    """
        Возвращает результат запроса по методу
        
        method: string
            метод из документации, который хотим использовать
            
        parameters: string
            параметры используемого метода
            
        token: string
            токен Oauth доступа
        
        version: string
            версия API
    """
    
    # составляем ссылку
    url = 'https://api.vk.com/method/{method}?{parameters}&access_token={token}&v={version}'
    url = url.format(method=method, parameters=parameters, token=token, version=version)
    # запрашиваем ссылку и переводим в json (словарь)
    response = requests.get(url).json()
    
    return response

# %% [markdown]
# Снова скачаем имя пользователя, чтобы убедиться, что всё работает

# %%
vkDownload('users.get','user_ids=21519895')

# %%
vkDownload('users.get','user_ids=21519895,1&fields=bdate,city')

# %% [markdown]
# Попробуем выкачать записи со стены

# %%
wall = vkDownload('wall.get','user_ids=21519895')

# %%
wall['response']

# %%
# обратимся к первой записи, которая лежит в поле response по ключу items
wall['response']['items']

# %% [markdown]
# ## Способ 2
#
# та же функция по сути

# %%
def vk_download1(method, parameters):
    url = 'https://api.vk.com/method/' + method + \
'?' + parameters + '&v=' + version + '&access_token=' + token
    
    response = requests.get(url)
    return response.json()['response']

# %%
wall = vk_download1('wall.get','user_ids=21519895')

# %%
wall

# %% [markdown]
# В принципе это всё. Дальнейшая стратегия будет такой: открываем документацию, находим нужные метод и параметры и применяем их.

# %% [markdown]
# # Забираем посты из групп

# %% [markdown]
# В качестве примера выбираем группу "хайер скул оф мемс" https://vk.com/hsemem

# %% [markdown]
# <img align="center" src="pictures/meme1.jpg" height="600" width="600">

# %%
group_id = '-139105204'

wall = vk_download1('wall.get','owner_id=' + group_id)
wall
# Out:
# {'count': 1541,
#  'items': [{'inner_type': 'wall_wallpost',
#    'comments': {'can_post': 0, 'count': 0, 'groups_can_post': True},
#    'marked_as_ads': 0,
#    'hash': 'ilVtltugSUBJVTll-U45eQa-6v0',
#    'type': 'post',
#    'push_subscription': {'is_subscribed': False},
#    'donut_miniapp_url': 'https://vk.com/app51528700#/?owner_id=-139105204&type=donut_badges&params=%257B%2522item_id%2522%253A%2522101801%2522%257D',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1740579372,
#       'id': 457269784,
#       'owner_id': -139105204,
#       'access_key': '0c84a8b691cf752443',
#       'post_id': 101798,
#       'sizes': [{'height': 73,
#         'type': 's',
#         'width': 75,
#         'url': 'https://sun1-85.userapi.com/s/v1/ig2/GbFs4Nwso2TT4soUbxHBohj8zXq5i9D2bF5AemiaDQEmAhaSTwsv90YGK6QNO58ELxQ6JuT2bE7SnsLECiBLWvo2.jpg?quality=95&as=32x31,48x47,72x70,108x106,160x156,240x235,360x352,480x469,540x528,640x625,720x704,1080x1056,1280x1251&from=bu&cs=75x73'},
#        {'height': 127,
#         'type': 'm',
#         'width': 130,
#         'url': 'https://sun1-85.userapi.com/s/v1/ig2/GbFs4Nwso2TT4soUbxHBohj8zXq5i9D2bF5AemiaDQEmAhaSTwsv90YGK6QNO58ELxQ6JuT2bE7SnsLECiBLWvo2.jpg?quality=95&as=32x31,48x47,72x70,108x106,160x156,240x235,360x352,480x469,540x528,640x625,720x704,1080x1056,1280x1251&from=bu&cs=130x127'},
#        {'height': 590,
#         'type': 'x',
#         'width': 604,
#         'url': 'https://sun1-85.userapi.com/s/v1/ig2/GbFs4Nwso2TT4soUbxHBohj8zXq5i9D2bF5AemiaDQEmAhaSTwsv90YGK6QNO58ELxQ6JuT2bE7SnsLECiBLWvo2.jpg?quality=95&as=32x31,48x47,72x70,108x106,160x156,240x235,360x352,480x469,540x528,640x625,720x704,1080x1056,1280x1251&from=bu&cs=604x590'},
#        {'height': 789,
#         'type': 'y',
#         'width': 807,
#         'url': 'https://sun1-85.userapi.com/s/v1/ig2/GbFs4Nwso2TT4soUbxHBohj8zXq5i9D2bF5AemiaDQEmAhaSTwsv90YGK6QNO58ELxQ6JuT2bE7SnsLECiBLWvo2.jpg?quality=95&as=32x31,48x47,72x70,108x106,160x156,240x235,360x352,480x469,540x528,640x625,720x704,1080x1056,1280x1251&from=bu&cs=807x789'},
}],
#       'text': '',
#       'user_id': 100,
#       'web_view_token': 'cb3465aa7cb4de6585',
#       'orig_photo': {'height': 748,
#        'type': 'base',
#        'url': 'https://sun1-19.userapi.com/s/v1/ig2/gq4b2cXmsFNtI4gcfm1_SiPUJyUQ_VZwZZPnI0TealH_sjJdPcaTIfLvEQSVcP9vDrEOpUuDRQH-8oBh_BSyacka.jpg?quality=95&as=32x29,48x44,72x66,108x99,160x146,240x219,360x328,480x438,540x493,640x584,720x657,820x748&from=bu',
#        'width': 820}}}],
#    'date': 1740585600,
#    'from_id': -139105204,
#    'id': 101799,
#    'is_favorite': False,
#    'likes': {'can_like': 1,
#     'count': 113,
#     'user_likes': 0,
#     'can_publish': 1,
#     'repost_disabled': False},
#    'owner_id': -139105204,
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'post_type': 'post',
#    'reposts': {'count': 29, 'user_reposted': 0},
#    'text': '',
#    'views': {'count': 3767}},
#   {'inner_type': 'wall_wallpost',
#    'comments': {'can_post': 0, 'count': 0, 'groups_can_post': True},
#    'marked_as_ads': 0,
#    'hash': 'B_VcN_uGdlSYjm0g-lzb8eA28pE',
#    'type': 'post',
#    'push_subscription': {'is_subscribed': False},
#    'donut_miniapp_url': 'https://vk.com/app51528700#/?owner_id=-139105204&type=donut_badges&params=%257B%2522item_id%2522%253A%2522101795%2522%257D',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1740490688,
#       'id': 457269781,
#       'owner_id': -139105204,
#       'access_key': 'dbee51d1235672b5fa',
#       'post_id': 101793,
#       'sizes': [{'height': 75,
#         'type': 's',
#         'width': 72,
#         'url': 'https://sun1-88.userapi.com/s/v1/ig2/iCCNfepwRdAYUngYYxh-TcAF6_Qrz_jaSaONrK57Wev1N405rGNWMougVYUWPgarYg_EuOSorme3WgS9pAEsiyMT.jpg?quality=95&as=32x33,48x50,72x75,108x112,160x166,240x249,360x374,480x498,540x561,640x664,720x747,1076x1117&from=bu&cs=72x75'},
#        {'height': 130,
#         'type': 'm',
#         'width': 125,
#         'url': 'https://sun1-88.userapi.com/s/v1/ig2/iCCNfepwRdAYUngYYxh-TcAF6_Qrz_jaSaONrK57Wev1N405rGNWMougVYUWPgarYg_EuOSorme3WgS9pAEsiyMT.jpg?quality=95&as=32x33,48x50,72x75,108x112,160x166,240x249,360x374,480x498,540x561,640x664,720x747,1076x1117&from=bu&cs=125x130'},
#        {'height': 604,
#         'type': 'x',
#         'width': 582,
#         'url': 'https://sun1-88.userapi.com/s/v1/ig2/iCCNfepwRdAYUngYYxh-TcAF6_Qrz_jaSaONrK57Wev1N405rGNWMougVYUWPgarYg_EuOSorme3WgS9pAEsiyMT.jpg?quality=95&as=32x33,48x50,72x75,108x112,160x166,240x249,360x374,480x498,540x561,640x664,720x747,1076x1117&from=bu&cs=582x604'},
#        {'height': 807,
#         'type': 'y',
#         'width': 777,
#         'url': 'https://sun1-88.userapi.com/s/v1/ig2/iCCNfepwRdAYUngYYxh-TcAF6_Qrz_jaSaONrK57Wev1N405rGNWMougVYUWPgarYg_EuOSorme3WgS9pAEsiyMT.jpg?quality=95&as=32x33,48x50,72x75,108x112,160x166,240x249,360x374,480x498,540x561,640x664,720x747,1076x1117&from=bu&cs=777x807'},
#        {'height': 1080,
#         'type': 'z',
#         'width': 1040,
#         'url': 'https://sun1-88.userapi.com/s/v1/ig2/iCCNfepwRdAYUngYYxh-TcAF6_Qrz_jaSaONrK57Wev1N405rGNWMougVYUWPgarYg_EuOSorme3WgS9pAEsiyMT.jpg?quality=95&as=32x33,48x50,72x75,108x112,160x166,240x249,360x374,480x498,540x561,640x664,720x747,1076x1117&from=bu&cs=1040x1080'},
}],
#       'text': '',
#       'user_id': 100,
#       'web_view_token': 'c2c7d33283337d8780',
#       'orig_photo': {'height': 1228,
#        'type': 'base',
#        'url': 'https://sun1-89.userapi.com/s/v1/ig2/jzkaBL1Oy2Ao30HHzgeDg9m1caq9gFokhhICgqDnzFtVzLdcuMHCEoJoFe3qvn02jIkchL4KUPSNW0_T_e6Sgjp_.jpg?quality=95&as=32x31,48x46,72x69,108x104,160x153,240x230,360x345,480x460,540x518,640x614,720x691,1080x1036,1280x1228&from=bu',
#        'width': 1280}}}],
#    'date': 1740298380,
#    'from_id': -139105204,
#    'id': 101788,
#    'is_favorite': False,
#    'likes': {'can_like': 1,
#     'count': 318,
#     'user_likes': 0,
#     'can_publish': 1,
#     'repost_disabled': False},
#    'owner_id': -139105204,
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'post_type': 'post',
#    'reposts': {'count': 82, 'user_reposted': 0},
#    'text': '',
#    'views': {'count': 8322}},
#   {'inner_type': 'wall_wallpost',
#    'comments': {'can_post': 0, 'count': 0, 'groups_can_post': True},
#    'marked_as_ads': 0,
#    'hash': 'XIUQF-zpbGA6FOVeicl2WBJIxtY',
#    'type': 'post',
#    'push_subscription': {'is_subscribed': False},
#    'donut_miniapp_url': 'https://vk.com/app51528700#/?owner_id=-139105204&type=donut_badges&params=%257B%2522item_id%2522%253A%2522101787%2522%257D',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1739883452,
#       'id': 457269774,
#       'owner_id': -139105204,
#       'access_key': '264e1b9b6a755fbef0',
#       'post_id': 101781,
#       'sizes': [{'height': 73,
#         'type': 's',
#         'width': 75,
#         'url': 'https://sun9-58.userapi.com/s/v1/ig2/tuvZKMhQTMrGgoY9q_cdfsPwdkKgsD5O9bXUX0GFb_1wer9FtSdWwSt5lbTUJSSp9dInSIxfREK3lEvxtWWxmJzI.jpg?quality=95&as=32x31,48x47,72x70,108x105,160x156,240x233,360x350,480x467,540x525,640x623,720x700,736x716&from=bu&cs=75x73'},
#        {'height': 126,
#         'type': 'm',
#         'width': 130,
#         'url': 'https://sun9-58.userapi.com/s/v1/ig2/tuvZKMhQTMrGgoY9q_cdfsPwdkKgsD5O9bXUX0GFb_1wer9FtSdWwSt5lbTUJSSp9dInSIxfREK3lEvxtWWxmJzI.jpg?quality=95&as=32x31,48x47,72x70,108x105,160x156,240x233,360x350,480x467,540x525,640x623,720x700,736x716&from=bu&cs=130x126'},
#        {'height': 588,
#         'type': 'x',
#         'width': 604,
#         'url': 'https://sun9-58.userapi.com/s/v1/ig2/tuvZKMhQTMrGgoY9q_cdfsPwdkKgsD5O9bXUX0GFb_1wer9FtSdWwSt5lbTUJSSp9dInSIxfREK3lEvxtWWxmJzI.jpg?quality=95&as=32x31,48x47,72x70,108x105,160x156,240x233,360x350,480x467,540x525,640x623,720x700,736x716&from=bu&cs=604x588'},
#        {'height': 716,
#         'type': 'y',
#         'width': 736,
#         'url': 'https://sun9-58.userapi.com/s/v1/ig2/tuvZKMhQTMrGgoY9q_cdfsPwdkKgsD5O9bXUX0GFb_1wer9FtSdWwSt5lbTUJSSp9dInSIxfREK3lEvxtWWxmJzI.jpg?quality=95&as=32x31,48x47,72x70,108x105,160x156,240x233,360x350,480x467,540x525,640x623,720x700,736x716&from=bu&cs=736x716'},
#        {'height': 126,
#         'type': 'o',
#         'width': 130,
#         'url': 'https://sun9-58.userapi.com/s/v1/ig2/tuvZKMhQTMrGgoY9q_cdfsPwdkKgsD5O9bXUX0GFb_1wer9FtSdWwSt5lbTUJSSp9dInSIxfREK3lEvxtWWxmJzI.jpg?quality=95&as=32x31,48x47,72x70,108x105,160x156,240x233,360x350,480x467,540x525,640x623,720x700,736x716&from=bu&cs=130x126'},
#        {'height': 195,
#         'type': 'p',
#         'width': 200,
#         'url': 'https://sun9-58.userapi.com/s/v1/ig2/tuvZKMhQTMrGgoY9q_cdfsPwdkKgsD5O9bXUX0GFb_1wer9FtSdWwSt5lbTUJSSp9dInSIxfREK3lEvxtWWxmJzI.jpg?quality=95&as=32x31,48x47,72x70,108x105,160x156,240x233,360x350,480x467,540x525,640x623,720x700,736x716&from=bu&cs=200x195'},
#        {'height': 311,
#         'type': 'q',
#         'width': 320,
#         'url': 'https://sun9-58.userapi.com/s/v1/ig2/tuvZKMhQTMrGgoY9q_cdfsPwdkKgsD5O9bXUX0GFb_1wer9FtSdWwSt5lbTUJSSp9dInSIxfREK3lEvxtWWxmJzI.jpg?quality=95&as=32x31,48x47,72x70,108x105,160x156,240x233,360x350,480x467,540x525,640x623,720x700,736x716&from=bu&cs=320x311'},
#        {'height': 496,
#         'type': 'r',
#         'width': 510,
#         'url': 'https://sun9-58.userapi.com/s/v1/ig2/tuvZKMhQTMrGgoY9q_cdfsPwdkKgsD5O9bXUX0GFb_1wer9FtSdWwSt5lbTUJSSp9dInSIxfREK3lEvxtWWxmJzI.jpg?quality=95&as=32x31,48x47,72x70,108x105,160x156,240x233,360x350,480x467,540x525,640x623,720x700,736x716&from=bu&cs=510x496'}],
#       'text': '',
#       'user_id': 100,
#       'web_view_token': '8cc901d1cb5b51beba',
#       'orig_photo': {'height': 716,
#        'type': 'base',
#        'url': 'https://sun9-58.userapi.com/s/v1/ig2/tuvZKMhQTMrGgoY9q_cdfsPwdkKgsD5O9bXUX0GFb_1wer9FtSdWwSt5lbTUJSSp9dInSIxfREK3lEvxtWWxmJzI.jpg?quality=95&as=32x31,48x47,72x70,108x105,160x156,240x233,360x350,480x467,540x525,640x623,720x700,736x716&from=bu',
#        'width': 736}}}],
#    'date': 1740200220,
#    'from_id': -139105204,
#    'id': 101787,
#    'is_favorite': False,
#    'likes': {'can_like': 1,
#     'count': 103,
#     'user_likes': 0,
#     'can_publish': 1,
#     'repost_disabled': False},
#    'owner_id': -139105204,
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'post_type': 'post',
#    'reposts': {'count': 14, 'user_reposted': 0},
#    'text': 'а плакать уже нечем…',
#    'views': {'count': 4214}},
#   {'inner_type': 'wall_wallpost',
#    'comments': {'can_post': 0, 'count': 0, 'groups_can_post': True},
#    'marked_as_ads': 0,
#    'hash': 'yaFnS4QT6iJE6aaSfUHWQuDxcIg',
#    'type': 'post',
#    'push_subscription': {'is_subscribed': False},
#    'donut_miniapp_url': 'https://vk.com/app51528700#/?owner_id=-139105204&type=donut_badges&params=%257B%2522item_id%2522%253A%2522101786%2522%257D',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1739883047,
#       'id': 457269773,
#       'owner_id': -139105204,
#       'access_key': '6c081550489a72e38f',
#       'post_id': 101780,
#       'sizes': [{'height': 75,
#         'type': 's',
#         'width': 69,
#         'url': 'https://sun9-77.userapi.com/s/v1/ig2/ghgnN3YgHaWyG3PVALhvo5i1YXlm8-0uTEZb0Bycgp-xwITY-FAvwQbAyrKpXf2JAns0rGf5MWSs7_X4oPS2GImK.jpg?quality=95&as=32x35,48x52,72x79,108x118,160x174,240x262,360x393,480x523,540x589,640x698&from=bu&cs=69x75'},
#        {'height': 130,
#         'type': 'm',
#         'width': 119,
#         'url': 'https://sun9-77.userapi.com/s/v1/ig2/ghgnN3YgHaWyG3PVALhvo5i1YXlm8-0uTEZb0Bycgp-xwITY-FAvwQbAyrKpXf2JAns0rGf5MWSs7_X4oPS2GImK.jpg?quality=95&as=32x35,48x52,72x79,108x118,160x174,240x262,360x393,480x523,540x589,640x698&from=bu&cs=119x130'},
#        {'height': 604,
#         'type': 'x',
#         'width': 554,
#         'url': 'https://sun9-77.userapi.com/s/v1/ig2/ghgnN3YgHaWyG3PVALhvo5i1YXlm8-0uTEZb0Bycgp-xwITY-FAvwQbAyrKpXf2JAns0rGf5MWSs7_X4oPS2GImK.jpg?quality=95&as=32x35,48x52,72x79,108x118,160x174,240x262,360x393,480x523,540x589,640x698&from=bu&cs=554x604'},
#        {'height': 698,
#         'type': 'y',
#         'width': 640,
#         'url': 'https://sun9-77.userapi.com/s/v1/ig2/ghgnN3YgHaWyG3PVALhvo5i1YXlm8-0uTEZb0Bycgp-xwITY-FAvwQbAyrKpXf2JAns0rGf5MWSs7_X4oPS2GImK.jpg?quality=95&as=32x35,48x52,72x79,108x118,160x174,240x262,360x393,480x523,540x589,640x698&from=bu&cs=640x698'},
#        {'height': 142,
#         'type': 'o',
#         'width': 130,
#         'url': 'https://sun9-77.userapi.com/s/v1/ig2/ghgnN3YgHaWyG3PVALhvo5i1YXlm8-0uTEZb0Bycgp-xwITY-FAvwQbAyrKpXf2JAns0rGf5MWSs7_X4oPS2GImK.jpg?quality=95&as=32x35,48x52,72x79,108x118,160x174,240x262,360x393,480x523,540x589,640x698&from=bu&cs=130x142'},
#        {'height': 218,
#         'type': 'p',
#         'width': 200,
#         'url': 'https://sun9-77.userapi.com/s/v1/ig2/ghgnN3YgHaWyG3PVALhvo5i1YXlm8-0uTEZb0Bycgp-xwITY-FAvwQbAyrKpXf2JAns0rGf5MWSs7_X4oPS2GImK.jpg?quality=95&as=32x35,48x52,72x79,108x118,160x174,240x262,360x393,480x523,540x589,640x698&from=bu&cs=200x218'},
#        {'height': 349,
#         'type': 'q',
#         'width': 320,
# ...
#       'text': '',
#       'user_id': 100,
#       'web_view_token': '9685d842389291c60f',
#       'orig_photo': {'height': 736,
#        'type': 'base',
#        'url': 'https://sun9-71.userapi.com/s/v1/ig2/yNaakUWAhHY5L09_Y94Z2XuwXVPdqNOm-IwDdhyO3XLu5GA_hL2DeuKxV_L4so0nMr5-EeRSA2HifA2354OKQtfb.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,736x736&from=bu',
#        'width': 736}}}],
#    'date': 1739277300,
#    'from_id': -139105204,
#    'id': 101767,
#    'is_favorite': False,
#    'likes': {'can_like': 1,
#     'count': 102,
#     'user_likes': 0,
#     'can_publish': 1,
#     'repost_disabled': False},
#    'owner_id': -139105204,
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'post_type': 'post',
#    'reposts': {'count': 34, 'user_reposted': 0},
#    'text': '',
#    'views': {'count': 4441}},
#   {'inner_type': 'wall_wallpost',
#    'comments': {'can_post': 0, 'count': 0, 'groups_can_post': True},
#    'marked_as_ads': 0,
#    'hash': 'zuv1yAWZOoOWjF_cy4n3U7eBPA8',
#    'type': 'post',
#    'push_subscription': {'is_subscribed': False},
#    'donut_miniapp_url': 'https://vk.com/app51528700#/?owner_id=-139105204&type=donut_badges&params=%257B%2522item_id%2522%253A%2522101766%2522%257D',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 
jpg?quality=95&as=32x31,48x47,72x70,108x105,160x156,240x234,360x351,480x468,540x527,640x625,720x703,1080x1054,1280x1249,1284x1253&from=bu&cs=510x498'}],
#       'text': '',
#       'user_id': 100,
#       'web_view_token': '35c95a350985610a4b',
#       'orig_photo': {'height': 1253,
#        'type': 'base',
#        'url': 'https://sun9-34.userapi.com/s/v1/ig2/N0-WRSwSgylIv7ae_G07tu8F5MkQfnSwdH1qz6_DzQEBGHxDBIH9G5qpnMnc-mNGC4WY4o6SJCYTCakt4dHahdum.jpg?quality=95&as=32x31,48x47,72x70,108x105,160x156,240x234,360x351,480x468,540x527,640x625,720x703,1080x1054,1280x1249,1284x1253&from=bu',
#        'width': 1284}}}],
#    'date': 1738690680,
#    'from_id': -139105204,
#    'id': 101762,
#    'is_favorite': False,
#    'likes': {'can_like': 1,
#     'count': 104,
#     'user_likes': 0,
#     'can_publish': 1,
#     'repost_disabled': False},
#    'owner_id': -139105204,
#    'post_source': {'platform': 'android', 'type': 'api'},
#    'post_type': 'post',
#    'reposts': {'count': 12, 'user_reposted': 0},
#    'text': '',
#    'views': {'count': 7795}},
#   {'inner_type': 'wall_wallpost',
#    'comments': {'can_post': 0, 'count': 0, 'groups_can_post': True},
#    'marked_as_ads': 0,
#    'hash': 'V4IPP0wBAlRsl3hVevtOykKlSC0',
#    'type': 'post',
#    'push_subscription': {'is_subscribed': False},
#    'donut_miniapp_url': 'https://vk.com/app51528700#/?owner_id=-139105204&type=donut_badges&params=%257B%2522item_id%2522%253A%2522101761%2522%257D',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1722951346,
#       'id': 457269547,
#       'owner_id': -139105204,
#       'access_key': '3e5a07623079d57919',
#       'post_id': 101442,
#       'sizes': [{'height': 70,
#         'type': 's',
#         'width': 75,
#         'url': 'https://sun9-37.userapi.com/s/v1/ig2/Od8Yz-VeHoyGZLO_KJZJtBA_e4q-LMCPahg4Yvmdl93pAEvXjty4JLDRNtX3KbIiQ7sXGmsn6v3IklbF1gHC1v-4.jpg?quality=95&as=32x30,48x45,72x67,108x101,160x149,240x224,360x336,480x447,540x503,640x597,720x671,1080x1007,1280x1193,1284x1197&from=bu&cs=75x70'},
#        {'height': 121,
#         'type': 'm',
#         'width': 130,
#         'url': 'https://sun9-37.userapi.com/s/v1/ig2/Od8Yz-VeHoyGZLO_KJZJtBA_e4q-LMCPahg4Yvmdl93pAEvXjty4JLDRNtX3KbIiQ7sXGmsn6v3IklbF1gHC1v-4.jpg?quality=95&as=32x30,48x45,72x67,108x101,160x149,240x224,360x336,480x447,540x503,640x597,720x671,1080x1007,1280x1193,1284x1197&from=bu&cs=130x121'},
#        {'height': 563,
#         'type': 'x',
#         'width': 604,
#         'url': 'https://sun9-37.userapi.com/s/v1/ig2/Od8Yz-VeHoyGZLO_KJZJtBA_e4q-LMCPahg4Yvmdl93pAEvXjty4JLDRNtX3KbIiQ7sXGmsn6v3IklbF1gHC1v-4.jpg?quality=95&as=32x30,48x45,72x67,108x101,160x149,240x224,360x336,480x447,540x503,640x597,720x671,1080x1007,1280x1193,1284x1197&from=bu&cs=604x563'},
#        {'height': 752,
#         'type': 'y',
#         'width': 807,
}],
#       'text': '',
#       'user_id': 100,
#       'web_view_token': '87af2fd019c12b5ab9',
#       'orig_photo': {'height': 1197,
#        'type': 'base',
#        'url': 'https://sun9-37.userapi.com/s/v1/ig2/Od8Yz-VeHoyGZLO_KJZJtBA_e4q-LMCPahg4Yvmdl93pAEvXjty4JLDRNtX3KbIiQ7sXGmsn6v3IklbF1gHC1v-4.jpg?quality=95&as=32x30,48x45,72x67,108x101,160x149,240x224,360x336,480x447,540x503,640x597,720x671,1080x1007,1280x1193,1284x1197&from=bu',
#        'width': 1284}}}],
#    'date': 1738517700,
#    'from_id': -139105204,
#    'id': 101761,
#    'is_favorite': False,
#    'likes': {'can_like': 1,
#     'count': 169,
#     'user_likes': 0,
#     'can_publish': 1,
#     'repost_disabled': False},
#    'owner_id': -139105204,
#    'post_source': {'platform': 'android', 'type': 'api'},
#    'post_type': 'post',
#    'reposts': {'count': 29, 'user_reposted': 0},
#    'text': '',
#    'views': {'count': 6742}}]}

# %%
wall.keys()
# Out:
# dict_keys(['count', 'items'])

# %%
wall['count']
# Out:
# 1541

# %%
len(wall['items'])
# Out:
# 20

# %%
from tqdm import tqdm_notebook
import time

n = vk_download1('wall.get','owner_id=' + group_id)['count']
n
# Out:
# 1541

# %%
infa = { 
    'id': [ ],
    'text': [ ],
    'likes': [ ],
}

for i in tqdm_notebook(range(0, 2000, 100)):
    time.sleep(0.4)
    wall = vk_download1('wall.get','owner_id=' + group_id + \
                       '&count=100&offset=' + str(i)
                      )['items']
    
    infa['likes'].extend([item['likes']['count'] for item in wall])
    infa['id'].extend([item['id'] for item in wall])
    infa['text'].extend([item['text'] for item in wall])
# Out:
# C:\Users\Kseniya\AppData\Local\Temp\ipykernel_5948\1755242519.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(0, 2000, 100)):
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
infa
# Out:
# {'id': [101801,
#   101800,
#   101799,
#   101795,
#   101794,
#   101790,
#   101788,
#   101787,
#   101786,
#   101785,
#   101783,
#   101782,
#   101776,
#   101774,
#   101772,
#   101771,
#   101767,
#   101766,
#   101762,
#   101761,
#   101760,
#   101758,
#   101756,
#   101753,
#   101752,
#   101749,
#   101746,
#   101745,
#   101744,
#   101743,
#   101737,
#   101736,
#   101734,
#   101733,
#   101732,
#   101731,
#   101730,
#   101729,
#   101728,
#   101723,
#   101722,
#   101721,
#   101720,
#   101719,
#   101715,
#   101714,
#   101713,
#   101704,
#   101703,
#   101702,
#   101701,
#   101700,
#   101699,
#   101698,
#   101696,
#   101694,
#   101693,
#   101684,
#   101683,
#   101682,
#   101681,
#   101678,
#   101677,
#   101676,
#   101675,
#   101674,
#   101673,
#   101672,
#   101671,
#   101667,
#   101666,
#   101665,
#   101661,
#   101660,
#   101659,
#   101656,
#   101654,
#   101653,
#   101652,
#   101650,
#   101649,
#   101646,
#   101639,
#   101638,
#   101637,
#   101634,
#   101633,
#   101632,
#   101630,
#   101628,
#   101626,
#   101624,
#   101616,
#   101612,
#   101611,
#   101609,
#   101607,
#   101604,
#   101603,
#   101602,
#   101602,
#   101601,
#   101600,
#   101599,
#   101598,
#   101597,
#   101596,
#   101595,
#   101594,
#   101592,
#   101591,
#   101590,
#   101589,
#   101588,
#   101587,
#   101586,
#   101584,
#   101582,
#   101581,
#   101579,
#   101578,
#   101576,
#   101575,
#   101574,
#   101573,
#   101572,
#   101571,
#   101570,
#   101569,
#   101568,
#   101567,
#   101566,
#   101565,
#   101564,
#   101563,
#   101561,
#   101559,
#   101558,
#   101557,
#   101556,
#   101555,
#   101554,
#   101553,
#   101551,
#   101550,
#   101549,
#   101548,
#   101547,
#   101546,
#   101545,
#   101544,
#   101543,
#   101540,
#   101539,
#   101538,
#   101537,
#   101535,
#   101534,
#   101532,
#   101531,
#   101530,
#   101529,
#   101528,
#   101527,
#   101526,
#   101525,
#   101524,
#   101523,
#   101522,
#   101521,
#   101520,
#   101519,
#   101518,
#   101517,
#   101516,
#   101515,
#   101514,
#   101512,
#   101511,
#   101510,
#   101509,
#   101506,
#   101505,
#   101504,
#   101503,
#   101502,
#   101501,
#   101500,
#   101499,
#   101498,
#   101497,
#   101496,
#   101495,
#   101491,
#   101490,
#   101487,
#   101486,
#   101485,
#   101484,
#   101483,
#   101482,
#   101481,
#   101480,
#   101479,
#   101478,
#   101453,
#   101452,
#   101451,
#   101450,
#   101449,
#   101448,
#   101447,
#   101414,
#   101413,
#   101412,
#   101411,
#   101410,
#   101373,
#   101360,
#   101359,
#   101358,
#   101357,
#   101355,
#   101354,
#   101352,
#   101350,
#   101347,
#   101345,
#   101343,
#   101341,
#   101340,
#   101339,
#   101338,
#   101335,
#   101334,
#   101331,
#   101330,
#   101329,
#   101328,
#   101327,
#   101325,
#   101323,
#   101322,
#   101321,
#   101320,
#   101319,
#   101317,
#   101316,
#   101315,
#   101313,
#   101312,
#   101311,
#   101310,
#   101308,
#   101307,
#   101305,
#   101304,
#   101303,
#   101302,
#   101301,
#   101300,
#   101299,
#   101298,
#   101297,
#   101296,
#   101294,
#   101293,
#   101291,
#   101290,
#   101289,
#   101288,
#   101286,
#   101283,
#   101280,
#   101278,
#   101277,
#   101275,
#   101274,
#   101273,
#   101272,
#   101271,
#   101268,
#   101267,
#   101266,
#   101264,
#   101262,
#   101261,
#   101260,
#   101259,
#   101257,
#   101256,
#   101253,
#   101252,
#   101251,
#   101250,
#   101249,
#   101248,
#   101247,
#   101246,
#   101245,
#   101244,
#   101243,
#   101242,
#   101241,
#   101240,
#   101239,
#   101238,
#   101237,
#   101236,
#   101235,
#   101234,
#   101233,
#   101232,
#   101231,
#   101230,
#   101229,
#   101228,
#   101227,
#   101226,
#   101225,
#   101224,
#   101223,
#   101222,
#   101221,
#   101220,
#   101219,
#   101218,
#   101217,
#   101216,
#   101215,
#   101214,
#   101213,
#   101212,
#   101167,
#   101166,
#   101165,
#   101164,
#   101163,
#   101162,
#   101161,
#   101160,
#   101159,
#   101158,
#   101157,
#   101156,
#   101155,
#   101154,
#   101153,
#   101152,
#   101151,
#   101150,
#   101149,
#   101148,
#   101147,
#   101146,
#   101145,
#   101144,
#   101143,
#   101142,
#   101141,
#   101140,
#   101139,
#   101138,
#   101137,
#   101136,
#   101135,
#   101134,
#   101133,
#   101132,
#   101131,
#   101127,
#   101126,
#   101125,
#   101124,
#   101123,
#   101122,
#   101094,
#   101093,
#   101079,
#   101078,
#   101077,
#   101076,
#   101075,
#   101074,
#   101072,
#   101071,
#   101070,
#   101055,
#   101054,
#   101053,
#   101052,
#   101051,
#   101050,
#   101047,
#   101046,
#   101045,
#   101041,
#   101040,
#   101039,
#   101037,
#   101036,
#   101035,
#   101032,
#   101031,
#   101030,
#   101028,
#   101027,
#   101026,
#   101024,
#   101023,
#   101021,
#   101019,
#   101017,
#   101016,
#   101015,
#   101014,
#   101012,
#   101009,
#   101008,
#   101007,
#   101006,
#   101005,
#   101004,
#   101003,
#   100999,
#   100998,
#   100997,
#   100994,
#   100993,
#   100992,
#   100991,
#   100989,
#   100988,
#   100987,
#   100986,
#   100985,
#   100984,
#   100983,
#   100982,
#   100981,
#   100980,
#   100978,
#   100977,
#   100976,
#   100975,
#   100973,
#   100972,
#   100971,
#   100970,
#   100969,
#   100968,
#   100967,
#   100965,
#   100964,
#   100963,
#   100962,
#   100961,
#   100960,
#   100959,
#   100958,
#   100957,
#   100956,
#   100953,
#   100952,
#   100951,
#   100950,
#   100946,
#   100945,
#   100944,
#   100942,
#   100941,
#   100940,
#   100936,
#   100935,
#   100934,
#   100933,
#   100932,
#   100931,
#   100929,
#   100928,
#   100927,
#   100926,
#   100923,
#   100920,
#   100919,
#   100918,
#   100914,
#   100913,
#   100910,
#   100909,
#   100905,
#   100895,
#   100883,
#   100843,
#   100842,
#   100840,
#   100839,
#   100838,
#   100836,
#   100835,
#   100830,
#   100829,
#   100828,
#   100826,
#   100823,
#   100821,
#   100818,
#   100816,
#   100813,
#   100812,
#   100811,
#   100810,
#   100807,
#   100806,
#   100805,
#   100804,
#   100802,
#   100801,
#   100799,
#   100796,
#   100795,
#   100793,
#   100792,
#   100791,
#   100787,
#   100786,
#   100783,
#   100782,
#   100780,
#   100778,
#   100776,
#   100774,
#   100772,
#   100771,
#   100770,
#   100767,
#   100762,
#   100761,
#   100757,
#   100739,
#   100735,
#   100733,
#   100730,
#   100722,
#   100720,
#   100715,
#   100703,
#   100700,
#   100696,
#   100695,
#   100676,
#   100672,
#   100668,
#   100667,
#   100659,
#   100653,
#   100642,
#   100622,
#   100618,
#   100599,
#   100593,
#   100589,
#   100588,
#   100585,
#   100584,
#   100578,
#   100577,
#   100575,
#   100574,
#   100569,
#   100564,
#   100562,
#   100560,
#   100551,
#   100541,
#   100540,
#   100537,
#   100530,
#   100526,
#   100524,
#   100520,
#   100519,
#   100514,
#   100509,
#   100507,
#   100506,
#   100505,
#   100498,
#   100496,
#   100493,
#   100485,
#   100483,
#   100478,
#   100477,
#   100473,
#   100468,
#   100465,
#   100461,
#   100460,
#   100456,
#   100451,
#   100446,
#   100443,
#   100434,
#   100398,
#   100395,
#   100390,
#   100376,
#   100361,
#   100358,
#   100352,
#   100350,
#   100345,
#   100344,
#   100341,
#   100340,
#   100325,
#   100321,
#   100319,
#   100315,
#   100314,
#   100311,
#   100308,
#   100306,
#   100305,
#   100303,
#   99099,
#   99098,
#   99096,
#   99094,
#   99089,
#   99087,
#   99086,
#   99083,
#   99081,
#   99078,
#   99070,
#   99066,
#   99057,
#   99053,
#   99045,
#   99040,
#   99037,
#   99029,
#   99027,
#   99024,
#   99017,
#   99016,
#   99011,
#   99006,
#   99002,
#   99000,
#   98994,
#   98991,
#   98986,
#   98980,
#   98976,
#   98975,
#   98965,
#   98962,
#   98961,
#   98956,
#   98942,
#   98933,
#   98932,
#   98931,
#   98919,
#   98915,
#   98911,
#   98906,
#   98902,
#   98901,
#   98898,
#   98893,
#   98888,
#   98887,
#   98878,
#   98874,
#   98869,
#   98864,
#   98859,
#   98849,
#   98848,
#   98844,
#   98842,
#   98838,
#   98835,
#   98827,
#   98815,
#   98810,
#   98806,
#   98794,
#   98791,
#   98789,
#   98781,
#   98779,
#   98776,
#   98772,
#   98770,
#   98758,
#   98753,
#   98743,
#   98739,
#   98727,
#   98722,
#   98719,
#   98713,
#   98696,
#   98695,
#   98693,
#   98689,
#   98685,
#   98678,
#   98673,
#   98666,
#   98659,
#   98653,
#   98650,
#   98640,
#   98639,
#   98606,
#   98587,
#   98579,
#   98574,
#   98566,
#   98564,
#   98558,
#   98550,
#   98547,
#   98535,
#   98532,
#   98530,
#   98529,
#   98524,
#   98522,
#   98517,
#   98516,
#   98515,
#   98509,
#   98507,
#   98505,
#   98487,
#   98484,
#   98481,
#   ...],
#  'text': ['',
#   '',
#   '',
#   '',
#   '',
#   'Место общения всей вышки! Больше в комментах 👇',
#   '',
#   'а плакать уже нечем…',
#   'ведь скоро сес си я',
#   'муд на ближайший месяц:',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'каждый понедельник одно и то же',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Место силы и общения всего ВШЭ! \nБольше в комментах👇',
#   'как выглядит чат с одногруппниками:',
#   '',
#   '',
#   '',
#   'Канал Полины Королевой💡\nt.me/yourtutorpolina\n\n10 лет экспертизы преподавания экономики и математики в Вышке. Личные проекты репетиторства и курсы.\n\nГруппы по макро МИЭФ, микро1 Эконом✍️\n\nПосле стольких лет. Всегда🪄',
#   'каждый самоуверенный перваш:',
#   'я каждое утро перед парами:',
#   '',
#   '',
#   '',
#   'пользуйся этой штукой почаще, а то совсем забыл про нее…',
#   '',
#   'Интенсивы по Calculus для МИЭФ, 1 курс\n🍪11 января, 19:00\n🍪12 января. 13:00\n\nСтоимость каждого 1990 \nВ день интенсива 2190 \n\n🖍️Напишите «calculus» в личку паблика, чтобы записаться: vk.me/hserepet',
#   '',
#   'и никуда не надо идти 🙌🏻',
#   '',
#   '[club227532133|@hserepet]',
#   '',
#   '',
#   '',
#   '',
#   'студент ВШЭ 😎😎😎😎',
#   '',
#   '',
#   '',
#   '',
#   'когда надо готовиться к сессии:',
#   'Оставь свой след в конкурсе и получи наушники, умную колонку и другие призы. Торопись, пока всё это не забрали — дедлайн уже 25 декабря. Подробности конкурса читай по ссылке: https://vk.com/wall-97845125_272808',
#   'студенты на вышмате:',
#   'МИЭФ, 1 курс, Statistics \nДата интенсива: 26 декабря (четверг), 19:00 \nСтоимость: 1 990 \nВ день интенсива: 2 190 \nЗаписаться: vk.me/hserepet',

#   '',
#   '',
#   '',
#   '',
#   '',
#   'муд на ближайшее время:',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'скоро ребятки, скоро',
#   '',
#   'записываем рецепт, ребятки',
#   '',
#   'препод, объявляя результаты экзамена: у всех хорошие оценки, кроме одного из вас\nя:',
#   '',
#   'когда не подготовился к экзамену и пытаешься вытянуть своими силами',
#   'сессия mood:',
#   'Сегодня интенсив по calculus для МИЭФ. Кто не записался, вы еще можете успеть. Напишите в личку паблика \n\nvk.me/hserepet',
#   '',
#   '',
#   '',
#   'Уже провели не один интенсив и студенты рады такой полезной подготовке. Успейте записаться на оставшиеся. Ищите свою программу и курс. \n\nДаты оставшихся интенсивов \n\n🔥Миэф 1 курс микро \n27 октября \n\n🔥Миэф 1 курс calculus \n29 октября \n\n🔥ПАД \n6 ноября \n\n⏰ Время 19:00\n\n🗓 Записаться: vk.me/hserepet',
#   'доброе сессионное утро',
#   '',
#   'первак в сентябре: думаю я справлюсь с учёбой в ВШЭ, главное стараться\nпервак щас:',
#   '',
#   '',
#   '',
#   '',
#   'перваш перед первым экзаменом:',
#   '',
#   '',
#   'я: *просыпаюсь утром*\nмой организм:',
#   '',
#   '',
#   'Запишись на интенсив для подготовки: vk.me/hserepet',
#   'выбор очевиден',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'я на экзамене по философии:',
#   'я и мои серьезные причины не ходить на пары:',
#   '',
#   'зацени впн админов https://vpnand.com/?ref=92\n\nскачивай, поддерживай вышкинцев и получай скидку 15%💙',
#   '',
#   '',
#   'я: *пишу преподу длинное сообщение связанное с учебой*\nпрепод:',
#   'Бабл ти можно пить перед парами, после пар и даже во время пары! А в Nova Bubble Tea это можно делать со скидкой 20% по предоставлению студака ВШЭ с 1 октября по 31 октября)\n\nАкция действует по адресам:\n📍Покровка 25\n📍Лубянский проезд 25с1',
#   '💪 Советы от опытного преподавателя 👋 для успешной подготовки к сессии \n\n1️⃣Обязательно выспись перед контрольной 😴\nУчить всю ночь бесполезно — информация лучше откладывается во время сна. Даже если волнуешься, попробуй выйти на прогулку хотя бы на полчаса, чтобы успокоиться и быстрее уснуть.\n\n2️⃣Прорешай задания прошлых лет\nМногие преподаватели не сильно изменяют задания из года в год. Решая прошлогодние варианты, ты значительно повысишь свои шансы на успех.🙂\n\n3️⃣Выясни формат контрольной заранее\nНе трать силы на разбор формата во время экзамена. Узнай всё заранее, чтобы быть готовым к любым вопросам и типам заданий.😥\n\n4️⃣Собери всё необходимое заранее\n– Полная бутылка воды (в прозрачной бутылке без этикетки) 🍵\n– Шоколадка для мозга 🍩\n– Тёплая кофта (в аудиториях бывает холодно из-за кондиционеров) 🙂\n– Две пишущие ручки ✍️\n– И обязательно сходи в туалет перед экзаменом! 🙂\n\n📊 Готовься с нами и повышай свои шансы на успех!\n\n🙂 Наши интенсивы помогут подготовиться к экзаменам эффективно и уверенно. Запишись уже сейчас!\n\n🤔Список интенсивов на октябрь: vk.com/wall-227532133_5\n\n💻 Записаться: vk.me/hserepet',
#   '',
#   '',
#   'первая неделя учёбы в одной картинке:',
#   '',
#   '',
#   '',
#   '',
#   'не 2 месяца, а 2 дня',
#   '🔥 Приглашаем на льготное обучение в автошколе с 17 лет для студентов и выпускников Вышки! \n\n🖊 Записаться возможно очно или дистанционно по форме: https://vk.com/app5708398_-88426871 или у Марии - https://vk.com/vorontsova_maria\n\n🚀 Полный курс за 24 990 - теория+практика\n\n🎁 Литература в подарок, теорию можно пройти дистанционно! \n\n❗Успейте принять участие в конкурсе: https://vk.com/wall-88426871_34079',
#   '',
#   'интроверты такие:',
#   '',
#   '',
#   'чистосердечное',
#   'перваки, у которых была пятидневка в школе такие:',
#   'Сдать IELTS? Легко! \n \nПриходите на бесплатный онлайн-практикум от школы Engvestors, чтобы разобраться в формате и построить свой план подготовки. После практикума вы точно будете знать, что делать, чтобы сдать на нужный балл. \n \n✨ Как не попасться на ловушки, расставленные авторами IELTS? \n \n✨ Как планировать подготовку, если в запасе есть год? А если только 2-3 месяца? \n \n✨ Как получить +1 балл благодаря знанию формата? \n \n29 августа в 19:00 академический директор школы Engvestors, расскажет о тонкостях экзамена и на реальных кейсах покажет, как можно выстроить стратегию подготовки в разных ситуациях и в любом случае получить нужный балл 🔥\n\n🗓 29 августа, четверг \n19:00 (по Московскому времени)\n  \nРегистрируйтесь на онлайн-практикум в Телеграм-боте: https://t.me/ielts_engvestors_bot/?erid=2Vtzqwe1k85\n\nРеклама \nИП Пучкова А.А. \nИНН 860802561988',
#   '',
#   '',
#   '',
#   'Когда учишь перваша выживанию в ВШЭ',
#   'когда отучился только год, а впереди ещё 3',
#   '',
#   'перваки такие:',
#   'mood:',
#   '',
#   '',
#   'староста: я говорила об этом в беседе, почитай\nбеседа группы:',
#   '',
#   '',
#   '',
#   'когда окончил вшэ и теперь нужно искать работу и вообще становиться взрослее',
#   'когда кореш предложил не поступать в магистратуру',
#   '',
#   'жиза',
#   'когда пишешь в конфу группы летом',
#   '',
#   '',
#   '',
#   '',
#   '"Лето — время для дел, которые не успел сделать во время учёбы"\nЯ:',
#   '',
#   '',
#   'когда отличник жалуется, что ему не поставили 10',
#   '',
#   '',
#   '',
#   '',
#   'Как выглядит курсач, из которого слили всю воду',
#   'моё общение с Chat GPT под конец учёбы:',
#   '',
#   '',
#   'Говорим главное, 2024 — год студентов в Vertigo Store \n \nОбещаем радовать вас предложениями только для своих и самыми лучшими ценами на гаджеты \n \nhttps://vk.com/vertigostore_msk \n \nПодпишись, чтобы не пропустить самые выгодные предложения 😈 \n \nРеклама, https://vertigostore.ru/?utm_source=vkontakte&utm_medium=cpc&utm_campaign=29',
#   'календарь уважающего себя студента:',
#   '',
#   '',
#   '',
#   'Перед тем как посмотреть свои баллы за семестр:',
#   '',
#   'Мама: пришли-ка мне результаты твоих экзаменов. \nЯ:',
#   '',
#   'выпускники такие:',
#   'когда сдал все экзамены и наконец-то можешь отдохнуть',
#   '',
#   'ВШЭ: у нас нормальная нагрузка, студенты все успевают и не выгорают \n \nтакже их студенты в коридорах:',
#   'когда закрыл сессию на «хорошо»',
#   '',
#   '',
#   '',
#   'тот самый опыт работы, который требуют после вуза\u2060\u2060',
#   'Когда с другом договорились вместе прогулять пары, а он взял и пришел на учебу',
#   '',
#   '',
#   '',
#   '',
#   'pov: за ночь перед защитой диплома',
#   'Когда почти закончил универ',
#   'Когда принес преподу курсач в 12-й раз, а он опять вносит правки и отправляет на доработку',
#   '',
#   '',
#   'когда спросили, почему ты выглядишь таким уставшим уже на 1 паре',
#   'наши экологичные отношения в групповом проекте',
#   '',
#   '',
#   'Когда на след день экзамен и ты решил за ночь быстренько выучить весь материал',
#   'Закажите картину в качестве подарка. Скажите «инжир» при заказе.',
#   '',
#   '',
#   'ВШЭ: учеба у нас — одно удовольствие! \nмимо проходящий 3 курсник:',
#   '',
#   '',
#   '',
#   '',
#   'смотришь на наивных абитуриентов, которые бегут подавать в ВШЭ:',
#   '',
#   '',
#   'В начале было слово… \n/start \nА затем \n/final_battle \nНо до финала нам нужно обогнать МАИ — погнали?',
#   '',
#   '',
#   'что мне дала учеба в вшэ:',
#   '',
#   '',
#   'как чувствуется чилл перед важным событием:',
#   '',
#   'как выглядит счастье',
#   '',
#   'мое состояние перед защитой',
#   '',
#   '',
#   '',
#   '',
#   '— привет у тебя же есть принтер, давай курсовую распеч...\nя:',
#   'это я на экзамене делаю вид, что вспоминаю то, чего не знаю',
#   '',
#   'Хочешь легко знакомиться с новыми друзьями?🤔\n\n"Санёк Зовет" - это сервис, который:\n\n⭐️Найдет друга для встречи, где и когда тебе удобно\n🤝Покажет приглашения на встречи от других пользователей\n😌И сделает это все безопасно и комфортно\n\nХочешь быть одним из первых пользователей такого технологического чуда?\n\nЗаполни заявку⬇️\n(Кол-во мест ограничено, 18+)\n\nhttps://forms.yandex.ru/u/663f653b02848f5365219484/',
#   'я под конец семестра пытаюсь сохранять спокойствие',
#   '',
#   '',
#   '',
#   'я: сел за диплом и создал титульник\nмой мозг:',
#   '',
#   '',
#   'я: задремал на последней парте\nпрепод:',
#   '',
#   '',
#   '',
#   'когда групповая работа с человеком, который неприятен',
#   '',
#   'когда звонишь маме и просишь перевести деньги на обед в столовке:',
#   'одногруппники: сидят записывают лекцию\nя:',
#   'препод: что вам непонятно?\nя:',
#   '',
#   '',
#   'отец на 4 курсе решил поинтересоваться моей жизнью:',
#   '',
#   '',
#   'когда к вам по обмену прислали студента и он еще не адаптировался',
#   'жиза',
#   'когда фоткаешь слайд презы вместо того чтобы переписывать его в тетрадь',
#   '',
#   '',
#   'я, когда опять напоминают, что надо писать диплом',
#   'когда охранник в универе посмотрел на твой студак:',
#   'жиза',
#   'жиза',
#   'когда пытаешься разговорить препода вместо того чтобы он вел пару',
#   '',
#   'исследования: людям чтобы высыпаться надо 7-8 часов\nстуденты ВШЭ:',
#   '',
#   'я: *первый раз вовремя скидываю работу преподу*\nпрепод:',
#   'А спонсор этого поста — мой диплом\nМой диплом:',
#   'когда писал диплом и лег подремать под утро',
#   'когда на экзамене начал отвечать по билету:',
#   '',
#   '',
#   'мой мозг на экзамене:',
#   '',
#   '',
#   'я: блин, учиться вообще не успеваю.\nтакже я весь день:',
#   '',
#   'ищу где на лице у меня написано "хочу ответить на вопрос препода"',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'я: в воскресенье точно встану пораньше , уберусь дома, займусь учебой\nя в воскресенье:',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'pov: ты студент-трудяга в ВШЭ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'когда выделил 15 минут на диплом:',
#   '',
#   '',
#   '',
#   '',
#   'Когда тебе предложили сделать важную часть в групповом проекте',
#   'студенты ВШЭ во время модуля be like:',
#   'когда препод который не нравится попросил что-то сделать:',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'научник сел проверять мой курсач',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'я: "изи, на месте разберусь"\nя на 1 вопросе экзамена:',
#   '',
#   'когда не получил заветную 6',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'когда уснул на первом дне в ВШЭ, а проснулся почти в конце учебного года',
#   'одногруппники: будем помогать друг другу в подготовке ведь мы все в одной лодке\n\nнаша лодка:',
#   'Не переживай, все сдадим и летом будем отдыхать',
#   '',
#   '',
#   'никто:\nмои мысли перед сном:',
#   'когда научрук говорит что завтра нужно показывать первую главу курсовой, а у тебя ничего нe готово:',
#   'Празднуем с пацанами закрытие сессии',
#   'pov: ты во время сессии',
#   '',
#   '',
#   '',
#   'когда еле живой, но сдал сессию',
#   'студенты такие:',
#   'когда сдал 10990029090 дедлайнов за модуль и тебя чутка глючит:',
#   'как я себя чувствую, когда выхожу с уника после закрытой сессии',
#   '',
#   '',
#   'я на экзамене по философии:',
#   '',
#   'mood:',
#   'pov: ты студент ВШЭ',
#   'моя ручка на очень важном экзамене:',
#   'когда пережил почти год в ВШЭ:',
#   '',
#   'дурацкий плагиат',
#   'когда хорошо сдал сессию, постарел на пару лет за неделю и под конец просто:',
#   'когда заканчиваются идеи для эссе',
#   '',
#   '',
#   '',
#   '',
#   'тебе надо выучить миллион всего за ночь, но ты решил прилечь на 5 минут:',
#   '',
#   '',
#   '',
#   '— Какой самый безумный поступок, который ты совершал ради денег?\n\nЯ:',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Я: откладываю подготовку к сессии на завтра.\nЗавтра наступает.\nЯ:',
#   '',
#   'дневник вышкинца',
#   '',
#   '',
#   '',
#   'Никто:\nСтуденты ВШЭ во время модуля:',
#   'а пора бы',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'готовишься к сессии, ведешь внеучебную деятельность, делаешь дз и пытаешься поддерживать менталку',
#   'препод: *задаёт доп. вопросы на экзамене* \nя:',
#   'ммммммммм',
#   'мой муж: я не ревнивый\nтакже мой муж:',
#   'когда всю ночь учил билеты, лег спать и через полчаса тебя будят на экзамен',
#   'когда начал сдавать долги за неделю до начала сессии:',
#   'студенты-географы едут на практику',
#   '',
#   'когда ждал этого 4 года',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'когда дед рассказывает про свою молодость',
#   '',
#   'препод приводит в пример свой же учебник',
#   '',
#   '',
#   '',
#   '',
#   'Родные утром: будят в универ \nЯ, поспавший 2 часа:',
#   '',
#   'переписка с научруком',
#   'Давайте поддержим',
#   'когда куратор пугает первашей ИУПом',
#   '',
#   'Опрос девушек: какой принт для шоппера вам наиболее нравится?',
#   'я: *просыпаюсь утром* \nмой организм:',
#   '',
#   'когда на четвёртом курсе вспоминаете свой первый курс',
#   'я и курсач',
#   'когда закончил универ \n\n*теперь вы раб капиталистической системы*',
#   'жиза',
#   'когда препод не хочет принимать твою работу',
#   'параллельные прямые которые никогда не пересекаются',
#   '',
#   '',
#   'ладно',
#   'лежишь в 8:00 и думаешь стоит ли первая пара всех этих мучений',
#   '',
#   '',
#   '',
#   '',
#   'Отличники по 4 года не постят ни одной фотки, а потом резко выкладывают вот такое',
#   '',
#   'а ещё модуль скоро...',
#   '',
#   'тот самый препод, который на модуле дает легкие задания:',
#   'абитуриенты щас',
#   'напоминаем💙',
#   '',
#   'препод: *ругает меня за опоздание* \nя:',
#   '',
#   'я: *указываю преподу на ошибку* \nпрепод:',
#   'каждый раз когда думаю прогулять пару или нет',
#   'никто:\nпрепод по философии:',
#   'уже скоро....',
#   'Вопрос к лицеистам.',
#   '',
#   'пошёл первым отвечать на модуле:',
#   'pov: ты учишься в ВШЭ',
#   '🚀Привет, друзья!🚀 \nМеня зовут Глеб. Я учусь в топовом итальянского университета Bocconi в Милане и получаю стипендию в 7.000 евро в год! Вместе с друзьями мы основали компанию Admittaly, чтобы поделиться этим опытом с тобой!\nХочешь учиться в Италии также как и мы? Хочешь узнать свои шансы на получение гранта на учебу в Италии? \n🌟Запишись на нашу БЕСПЛАТНУЮ консультацию, заполнив гугл форму по ссылке https://forms.gle/gWudnjYrDNSS9qUp8',
#   'когда все отложил на последнюю ночь перед дедлайном',
#   'когда всю ночь потратил на задание и спал 2 часа, но довольный за результат встаешь в универ',
#   'я: знаю на 4\nпрепод: ставит 7\nя:',
#   'когда подсказал другу неправильный ответ и теперь его мучает препод:',
#   'Супер-новости для любителей японской культуры💥\n\nЯпонское бистро [club41978256|J’PAN] завтра открывается на Пятницкой! Ребята обновили меню и добавили много крутых позиций 💔\n\nА ещё специально для наших подписчиков сделали промокод «СКУЛ» на скидку -20% в новом бистро до 10 марта🫂\n\n📍ул. Пятницкая, 6/1',
#   '',
#   '',
#   'я: *опаздываю на 1 минуту* \nпрепод:',
#   'муд:',
#   'тот самый препод:',
#   '',
#   'когда препод выгнал из аудитории и ты гуляешь по территории универа ожидая что твоего друга тоже выгонят',
#   '',
#   '',
#   '',
#   '*учеба в ВШЭ* \nожидание:  новые знакомства, веселье, доп. активности\nреальность:',
#   'когда ты на 1 курсе, а мама уже намекает на подработку',
#   '',
#   '',
#   'это я проснулся к первой паре и пытаюсь понять стоит ли она этих страданий',
#   'препод: все поняли тему? \nя, который понял, что мне надо ботать весь вечер чтобы это понять:',
#   '',
#   '',
#   'препод на консультации:',
#   'когда поругался с преподом и теперь тебя тащат в деканат:',
#   'начало семестра vs модульная неделя\n\np.s. не повторяйте ошибок прошлого',
#   '',
#   '',
#   'мы с дружком-пирожком на любой паре',
#   'я: *решаю написать курсач, заботать темы наперед* \nмоя лень:',
#   'когда ты не посещал пары и тебе приходит на почту письмо от препода:',
#   'когда думал, что задание изи и отложил на последний момент, а потом понял, что тут на целую ночь:',
#   '',
#   'я: *решаю написать курсач, заботать темы наперед* \nмоя лень:',
#   '',
#   'Когда тебя решили угостить комплексом:',
#   'когда видишь друга, который еле закончил бакалавр, а теперь поступил в магу и ноет, как ему сложно',
#   '',
#   'тут самый друг полуфабрикат на экзамене:',
#   '',
#   '',
#   'Гайд по корпусам вышки',
#   '',
#   '',
#   'Препод: *отодвигает дедлайн* \nТот самый чел, который делал работу всю ночь:',
#   '',
#   'Когда вспоминаешь себя на 1 курсе:',
#   'Когда в этом году заканчиваешь универ, но все равно такой:',
#   'Подпишись на наш телеграм https://t.me/hse_mem',
#   'напоминаем💙',
#   '',
#   '',
#   'собачникам привет',
#   'когда целый день не думал о том, чтобы кардинально поменять жизнь, взять академ и уехать жить в лес',
#   '',
#   'когда на протяжении всех пар вёл конспект, у тебя разборчивый почерк и твои одногруппники об этом знают',
#   '',
#   '',
#   '',
#   'когда доделываешь в последние минуты, но все равно доволен своей работой:',
#   'Когда препод увлечен подачей материала, а вы искренне вникаете в суть лекции и наслаждаетесь ей',
#   'HR: почему вы решили, что вы стрессоустойчивый?\nя, который прошел медные трубы в ВШЭ:',
#   'Другие студенты: хорошо учатся, ездят на олимпиады, получают гранты, создают бизнес, прославляют ВШЭ\nТем временем я:',
#   'Когда отвечал у доски, начал сыпаться и преподаватель вышел тебя выручить',
#   'Я перед тем, как выйти из дома на пары',
#   '',
#   '',
#   '',
#   'Когда учишь перваша выживанию в ВШЭ',
#   'типичный студент ВШЭ в конце недели:',
#   '',
#   '',
#   '',
#   '',
#   'по 100 раз на день',
#   '',
#   'pov: ты сел делать дедлайн',
#   'у кого доступ к cbonds есть? напишите плиз vk.me/hsemem',
#   'Когда тебе единственному из группы поставили более-менее балл:',
#   'Когда во время лекции не расслышал препода, переспросил 2 раза, но все равно не понял:',
#   '',
#   '',
#   'Когда неделю писал работу и видишь только 12% оригинальности',
#   '',
#   'Мы с одногруппниками пытаемся сделать за час проект, на который давалась неделя:',
#   'каждый уважающий себя старшекурсник:',
#   'фух сейчас в восресенье столько всего успею столько всего переделаю \n \nреальность:',
#   'как перваши видят ВШЭ в сентябре vs сейчас',
#   '',
#   'препод: я буду непредвзят, объективен! никаких двойных стандартов! \n\nтакже личности препода внутри:',
#   'тот самый одногруппник который читает сообщения в беседе, но никогда не пишет',
#   'когда проснулся и увидел, что только середина ночи и продолжаешь себе спать:',
#   'Что студенту нужно для счастья? \n\n#ВечернийХсеМем',
#   'рецепт успешной работы:',
#   'я в сотый раз отправляю преподу дз vs препод в 101-й раз требует исправить:',
#   '',
#   'pov: ты студент ВШЭ',
#   'То прекрасное чувство, когда доделал работу и закрываешь 30 вкладок в браузере:',
#   '',
#   'устроился на первую работу/стажировку и сидишь такой:',
#   'жду открытия филиала вышки в вышке\n\n(нижегородская область)',
#   '',
#   'проснулся к первой паре и обдумываю все исходы событий, если я не пойду:',
#   '',
#   '',
#   'p.s. автор такой красивый, что мы скрыли',
#   'как я себя чувствую, когда прихожу на пару после 1 дня пропуска:',
#   'когда не подготовился к практике и надо отвечать:',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'как я себя чувствую в субботу:',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'я на каникулах: буду этот семестр активным, займусь спортом, буду много ботать, повышу рейтинг\n\nя после 2х недель учебы:',
#   'когда пропустил 1 день в ВШЭ:',
#   '',
#   'Вакансии публикуем \nза 3000 р.',
#   'когда на паре делаешь умный вид, но при этом абсолютно ничего не понимаешь:',
#   '',
#   'препод: все поняли тему?\nмы с другом:',
#   'Привет, крутые хомячки! 🌟 \nГлеб, решил рискнуть и поступить в крутой итальянский университет Боккони. И что вы думаете? Он не только учится бесплатно, но и получает стипендию 7000 евро в год. Почему он, а не я? - спросите вы. Ну так и спросите у него на бесплатном вебинаре.\n📆 Дата: 23.01.2024 🕒 Время: 18:00\nФорма для регистрации❗:\nhttps://forms.gle/toQyQDiFZuF9hEJM9',
#   '',
#   'по дороге в универ задумался о том нужна ли мне эта учеба или все таки в академ:',
#   '',
#   'я: я учусь на программиста \nкто-то: о, а можешь... \nя:',
#   '',
#   'кто-то: что тебе дали годы учебы в ВШЭ? \nя:',
#   '',
#   '',
#   '',
#   '',
#   'Кто-то: наверное в ВШЭ не так уж сложно учиться\nЯ:',
#   'я, который все еще не хочет адаптироваться к учебе после каникул:',
#   '',
#   '',
#   'кто-то: ну как твой курсач? половину уже написал?\n\nя:',
#   'как я себя чувствую в первые дни учебы',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'когда ты уже не 1 курс, но все равно чувствуешь себя вот так:',
#   '',
#   '',
#   '',
#   '',
#   'первак, получивший 4 по бжд и слетевший со скидки, в центре психологической поддержки ВШЭ:',
#   '',
#   'подписывайтесь - https://t.me/hse_mem',
#   'до чего додумались?',
#   'когда в ВШЭ каникулы:',
#   'Поступаю в ВШЭ:',
#   'Препод: ваша оценка — шесть\nОценка на самом деле:',
#   'Когда наконец вышел на каникулы после того, как привык 24/7 делать задания и беспокоиться о ближайших дедлайнах весь семестр:',
#   'твоя мама, когда узнала что случилось со скидкой её замечательного ребенка:',
#   '',
#   '',
#   '',
#   'but before you live at HSE....',
#   'результаты: *приходят*\nматематичка:',
#   '',
#   'когда препод поставил на балл ниже, но тебе лень готовиться и пересдавать:',
#   'все: *планируют отдых на каникулы*\n\nя: смотрю на список всего, что надо учить для пересдачи',
#   'когда в коридоре заметил того самого препода, который не оценил твоих блестящих знаний и занизил балл:',
#   '',
#   'готовьтесь...',
#   '',
#   'я, все зимние каникулы строчу свой курсач:',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'pov: ты на первой работе/стажировке',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'где-то в дебрях покры...',
#   '',
#   '',
#   'тот самый друг',
#   '',
#   '',
#   '*в группе*: "он ставит всем автоматы, БЫСТРЕЕ СЮДА"\nя:',
#   '',
#   'Сейчас идут выборы уполномоченного по правам студентов ВШЭ, на них идёт Альберт Круглов.\n\nПочему в Университете нужен независимый омбудсмен и почему нужно поддержать Альберта?\n• Для помощи студентам во всех аспектах правозащиты\n• Возобновления работы комиссии по противодействию харассменту\n• Развития гражданского общества внутри Университета путем сохранения свободы самоуправления и развития правозащиты\n\nЕсли вы хотите, чтобы студенчество продолжало жить – голосуйте за Альберта Круглова до 25 декабря по ссылке из этого поста или из вашей корпоративной почты!\n\nСсылка на голосование (Альберт будет на последней странице):\nvote.studsovet.me',
#   'я, который только закончил 91928 дедлайн, спавший 4 часа, смотрю урок на ютубе для завтрашнего экзамена:',
#   'Если у вас не также не пишите мне',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'еще не суббота, а я чувствую себя вот так:',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Я уже сегодня чувствую как устану завтра…',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Все анонимно пожалуйста \n\n______\n\nМы против алкоголя! Кто пьет, тот слабак!',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Автор очень красивый, поэтому публикуем анонимно!!!!!\n\nP.S. \nАвтор не выдавай себя в комментариях!!!!!!\n\nP.P.S\nМем реально оч классный. 🌝❤️',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'когда все таки решил поехать на пары, а не поспать:',
#   '',
#   'я и научник',
#   '',
#   'pov: ты студентка ВШЭ',
#   '',
#   'когда сам загнал себя в безвыходное положение с багажом долгов:',
#   '',
#   'я в сентябре vs я в декабре',
#   'фото в цвете:',
#   '',
#   '',
#   '',
#   '',
#   'Марии Платоновой запросили 7 лет колонии.\n \nМаша - наш редактор и дорогой нам всем человек. \nМы уже писали о ней, когда её задержали 2 года назад, но это безумство тянется так долго, что многие из вас не знают про неё. \nНо мы хотим, чтобы как можно больше людей знало про Машу и её историю.\n \nМашу задержали 16 сентября 2021, когда она ещё училась на 3 курсе в Школе Дизайна в Москве. С тех пор Маша находится под домашним арестом. \nЕё обвиняют в участии в анонимном телеграм-чате, "направленном на склонение к массовым беспорядкам в дни единого голосования 2021 года". \n \nЕсли кратко, дело политическое. Конечно же, реальных доказательств причастности Маши нет и быть не может. Есть противоречия, указывающие на то, что это не Маша скрывалась под псевдонимом в чате, и даже есть показания другой девушки, которая признавалась, что она использовала такой псевдоним.\n \nМы убеждены, что Маша оказалась в этой ситуации случайно. Для дела не хватало человека и выбрали её. До Ареста Маша работала в предвыборном штабе Анастасии Брюхановой в Москве, и у неё был 1 арест за раздачу листовок ОВД-Инфо "Как вести себя при задержании" на митинге. \n \nТеперь в суде начнутся прения сторон, и затем вынесение приговора.\n\nЭтим рассказом мы ни к чему не призываем. Но мы хотим, что бы вы знали о Маше. Ссылок на статьи СМИ-иноагентов не прикладываем, но всё гуглится.\n \n[https://vk.com/wall-139105204_80874|В комментариях к этому посту], мы персонально рассказывали про Машу. \n \nА здесь вы можете посмотреть на её творчество: https://www.behance.net/maffkap',
#   '',
#   '',
#   'В комментарии кидайте фотографии корпусов Вышки, которые вы сами сделали',
#   '',
#   '',
#   '',
#   'Планирую написать курсач за декабрь - январь.',
#   '',
#   'Делитесь, как вы боретесь с перегоранием? Что вам лучше всего помогает?\n\n#ВечернийХсеМем',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'когда вместо отдыха делаешь 90432259910086204 домашку',
#   '',
#   '',
#   '',
#   '',
#   'и так каждое утро',
#   'Теперь вы можете заказать цветы через нас и наших партнеров по выгодной цене с дополнительной гарантией от нашего неформального вышкинского сообщества:\n\nДля вас мы можем:\n- собрать любой букет по фотографии\n- доставить в течение 30 минут букет\n- доставить цветы даже ночью \n\nЗаказ можно сделать, написав в личные сообщения по ссылке: vk.me/hsemem\n\nПомимо букетов, которые мы будем публиковать, вы можете отправлять любой референс из интернета.\n\nИ подписывайтесь на телеграм канал нашего цветочного магазина t.me/flowery_butik\n\nЦена букета на фото: 4 500 р.',
#   'и все равно умудриться сдать в последние минуты до дедлайна',
#   'научник и его поправки:',
#   '',
#   '',
#   '',
#   'Найди себя',
#   '',
#   '',
#   'и так каждый раз',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'когда не готовился и пытаешься угадать правильный ответ по реакции препода',
#   'мы с корешем после "достаем листочки"',
#   '',
#   '',
#   'я после 5 минут каждой пары',
#   '',
#   '',
#   '',
#   '🔺 Все старые друзья заняты? А все-таки хочется поговорить по душам за чашечкой кофе.\n\n🤔 Многие мои знакомые поделились со мной, что им не хватает общения. Мне тоже иногда не с кем встретиться поболтать. \n\n🏄\u200d♂ Для таких же как я запускаю проект по поиску друзей. Пройди тест на дружескую совместимость и выбери время и место для встречи.\nСсылка на тест: https://clck.ru/36cu4h\n\n📲 В результате тебе придет сообщение с приглашением на встречу.\n\n⚙️ Ваши ответы обрабатывает алгоритм, данные строго конфиденциальны.\n\n_____\n\nЭто проект от наших друзей вышкинцев (с) редактор',
#   'Когда только пришел домой и осознаешь сколько лаб/дз надо делать, а у тебя даже на переодеться сил нет',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Когда колени уже не выдерживают лекции на Покровке',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Проверить интуицию и узнать больше про ИТ\n\nКРОК собрал необычные факты про работу в ИТ и запустил квиз-бот https://t.me/CROC_work_bot/?erid=LjN8KE6ai\n\nДовериться шестому чувству и попробовать отличить ложь от правды — занятие на сегодня. Чем больше правильных ответов, тем выше шанс выиграть призы от КРОК 💚\n\nРеклама. Рекламодатель ЗАО «КРОК инкорпорейтед».',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Анонимно, пожалуйста :)',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Анонимно пж',
#   '',
#   '',
#   '',
#   '',
#   'Мем делал на коленке. Не ругайтесь',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'та самая рандомная мысль в два часа ночи:',
#   '🔥 Приглашаем на льготное обучение в автошколе с 17 лет для студентов и выпускников Вышки! Есть возможность обучения в Москве или в Одинцово\n\n🖊 Записаться возможно очно или дистанционно по форме: https://vk.com/app5708398_-88426871 или у Марии - https://vk.com/vorontsova_maria\n\n🚀 Полный курс за 24 990 - теория+практика\n\n🎁 Литература в подарок, теорию можно пройти дистанционно!\n\nТак же приглашаем вас принять участие в конкурсе репостов!\nhttps://vk.com/autohigh?w=wall-88426871_30541',
#   '',
#   'Когда пишешь работу в последний день ее сдачи',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ...],
#  'likes': [9,
#   139,
#   113,
#   44,
#   176,
#   124,
#   318,
#   103,
#   108,
#   73,
#   142,
#   224,
#   209,
#   80,
#   154,
#   173,
#   102,
#   103,
#   104,
#   169,
#   57,
#   155,
#   103,
#   0,
#   239,
#   274,
#   115,
#   193,
#   186,
#   105,
#   1,
#   199,
#   171,
#   92,
#   376,
#   235,
#   96,
#   203,
#   2,
#   174,
#   339,
#   163,
#   11,
#   260,
#   212,
#   193,
#   174,
#   606,
#   210,
#   177,
#   237,
#   171,
#   215,
#   5,
#   167,
#   2,
#   140,
#   6,
#   134,
#   232,
#   1,
#   289,
#   1,
#   189,
#   549,
#   1,
#   325,
#   2,
#   227,
#   1,
#   207,
#   409,
#   200,
#   710,
#   203,
#   143,
#   123,
#   539,
#   218,
#   126,
#   374,
#   112,
#   569,
#   199,
#   4,
#   184,
#   314,
#   23,
#   2,
#   409,
#   372,
#   1,
#   389,
#   563,
#   226,
#   324,
#   367,
#   1,
#   0,
#   199,
#   199,
#   213,
#   597,
#   776,
#   374,
#   231,
#   300,
#   136,
#   424,
#   2,
#   3,
#   136,
#   309,
#   3,
#   230,
#   228,
#   170,
#   486,
#   1,
#   1,
#   273,
#   205,
#   178,
#   0,
#   254,
#   18,
#   244,
#   10,
#   249,
#   519,
#   1,
#   0,
#   159,
#   428,
#   406,
#   187,
#   243,
#   1,
#   32,
#   197,
#   393,
#   191,
#   32,
#   5,
#   284,
#   2,
#   1,
#   234,
#   341,
#   3,
#   215,
#   1001,
#   108,
#   5,
#   2,
#   385,
#   283,
#   332,
#   2,
#   305,
#   3,
#   1,
#   528,
#   1614,
#   267,
#   610,
#   466,
#   58,
#   241,
#   516,
#   646,
#   140,
#   4,
#   300,
#   615,
#   278,
#   3,
#   271,
#   264,
#   930,
#   626,
#   477,
#   324,
#   355,
#   143,
#   1,
#   139,
#   458,
#   278,
#   323,
#   407,
#   266,
#   7,
#   594,
#   498,
#   423,
#   282,
#   201,
#   265,
#   586,
#   425,
#   288,
#   217,
#   564,
#   631,
#   1011,
#   398,
#   305,
#   361,
#   210,
#   390,
#   290,
#   273,
#   219,
#   824,
#   538,
#   308,
#   121,
#   384,
#   328,
#   496,
#   522,
#   737,
#   1318,
#   413,
#   166,
#   654,
#   362,
#   5,
#   522,
#   271,
#   483,
#   243,
#   528,
#   201,
#   399,
#   93,
#   644,
#   535,
#   362,
#   1881,
#   260,
#   82,
#   4,
#   5,
#   1584,
#   478,
#   418,
#   646,
#   3,
#   656,
#   325,
#   1127,
#   316,
#   59,
#   1339,
#   341,
#   135,
#   637,
#   429,
#   451,
#   4,
#   572,
#   764,
#   675,
#   942,
#   355,
#   263,
#   65,
#   653,
#   40,
#   316,
#   677,
#   473,
#   148,
#   339,
#   239,
#   841,
#   455,
#   344,
#   324,
#   60,
#   236,
#   953,
#   488,
#   44,
#   380,
#   80,
#   891,
#   1062,
#   3,
#   370,
#   851,
#   654,
#   2,
#   426,
#   58,
#   68,
#   246,
#   190,
#   102,
#   553,
#   433,
#   272,
#   347,
#   332,
#   407,
#   78,
#   1230,
#   1011,
#   60,
#   509,
#   301,
#   98,
#   791,
#   362,
#   823,
#   435,
#   220,
#   28,
#   492,
#   184,
#   161,
#   407,
#   861,
#   1170,
#   564,
#   470,
#   176,
#   756,
#   726,
#   315,
#   208,
#   727,
#   753,
#   91,
#   297,
#   717,
#   0,
#   97,
#   1033,
#   66,
#   559,
#   217,
#   2,
#   388,
#   65,
#   682,
#   508,
#   483,
#   85,
#   1414,
#   156,
#   554,
#   241,
#   770,
#   724,
#   71,
#   837,
#   645,
#   1019,
#   859,
#   493,
#   89,
#   540,
#   193,
#   183,
#   160,
#   136,
#   657,
#   147,
#   460,
#   281,
#   596,
#   391,
#   1785,
#   74,
#   233,
#   657,
#   44,
#   378,
#   314,
#   157,
#   46,
#   1055,
#   882,
#   54,
#   354,
#   1,
#   2,
#   624,
#   961,
#   646,
#   853,
#   72,
#   1449,
#   122,
#   286,
#   476,
#   362,
#   439,
#   658,
#   247,
#   251,
#   253,
#   305,
#   459,
#   588,
#   1060,
#   488,
#   833,
#   663,
#   316,
#   457,
#   301,
#   238,
#   65,
#   162,
#   823,
#   134,
#   635,
#   343,
#   464,
#   380,
#   1008,
#   1552,
#   15,
#   1624,
#   537,
#   390,
#   310,
#   268,
#   84,
#   926,
#   377,
#   613,
#   29,
#   32,
#   547,
#   273,
#   304,
#   311,
#   308,
#   17,
#   228,
#   1031,
#   781,
#   243,
#   816,
#   78,
#   863,
#   29,
#   92,
#   497,
#   213,
#   195,
#   1479,
#   569,
#   888,
#   228,
#   26,
#   189,
#   206,
#   510,
#   1162,
#   1085,
#   242,
#   332,
#   170,
#   1048,
#   81,
#   458,
#   1177,
#   47,
#   406,
#   546,
#   839,
#   3,
#   532,
#   379,
#   3,
#   482,
#   49,
#   508,
#   1180,
#   444,
#   92,
#   260,
#   415,
#   152,
#   977,
#   1524,
#   255,
#   312,
#   186,
#   204,
#   269,
#   1746,
#   140,
#   898,
#   982,
#   275,
#   874,
#   290,
#   741,
#   361,
#   42,
#   664,
#   544,
#   480,
#   262,
#   62,
#   195,
#   210,
#   1215,
#   3,
#   464,
#   253,
#   757,
#   162,
#   12,
#   424,
#   198,
#   162,
#   898,
#   782,
#   1026,
#   700,
#   433,
#   884,
#   1509,
#   776,
#   316,
#   328,
#   43,
#   239,
#   398,
#   1252,
#   697,
#   830,
#   277,
#   578,
#   235,
#   1134,
#   342,
#   387,
#   664,
#   407,
#   650,
#   333,
#   1360,
#   222,
#   221,
#   94,
#   485,
#   1380,
#   250,
#   1414,
#   1240,
#   1394,
#   677,
#   988,
#   226,
#   755,
#   20,
#   188,
#   292,
#   0,
#   761,
#   362,
#   725,
#   345,
#   251,
#   43,
#   9,
#   368,
#   1023,
#   1205,
#   536,
#   546,
#   233,
#   448,
#   1576,
#   839,
#   338,
#   468,
#   330,
#   907,
#   599,
#   616,
#   856,
#   296,
#   946,
#   3,
#   246,
#   281,
#   2,
#   640,
#   356,
#   1105,
#   1049,
#   674,
#   303,
#   782,
#   1647,
#   250,
#   253,
#   234,
#   36,
#   1102,
#   463,
#   422,
#   1038,
#   1274,
#   531,
#   748,
#   535,
#   410,
#   858,
#   304,
#   334,
#   270,
#   227,
#   311,
#   312,
#   507,
#   710,
#   2,
#   683,
#   491,
#   570,
#   13,
#   632,
#   571,
#   24,
#   1206,
#   893,
#   8,
#   1,
#   214,
#   1080,
#   445,
#   11,
#   453,
#   406,
#   2218,
#   336,
#   438,
#   794,
#   669,
#   402,
#   414,
#   513,
#   484,
#   386,
#   796,
#   946,
#   488,
#   596,
#   1,
#   449,
#   401,
#   1063,
#   357,
#   203,
#   509,
#   708,
#   972,
#   775,
#   834,
#   908,
#   582,
#   5,
#   279,
#   2190,
#   1400,
#   709,
#   1650,
#   619,
#   542,
#   793,
#   617,
#   482,
#   190,
#   0,
#   675,
#   460,
#   322,
#   338,
#   319,
#   869,
#   1215,
#   576,
#   1343,
#   911,
#   396,
#   1085,
#   456,
#   1067,
#   1701,
#   2550,
#   824,
#   333,
#   402,
#   756,
#   260,
#   574,
#   1040,
#   437,
#   1466,
#   325,
#   553,
#   1184,
#   329,
#   301,
#   33,
#   1485,
#   164,
#   611,
#   270,
#   671,
#   707,
#   767,
#   473,
#   582,
#   242,
#   1613,
#   1046,
#   912,
#   988,
#   1413,
#   407,
#   548,
#   1936,
#   596,
#   537,
#   1863,
#   460,
#   362,
#   552,
#   350,
#   753,
#   655,
#   883,
#   753,
#   645,
#   702,
#   359,
#   310,
#   756,
#   2,
#   675,
#   640,
#   541,
#   745,
#   951,
#   308,
#   387,
#   562,
#   470,
#   336,
#   1018,
#   767,
#   189,
#   786,
#   695,
#   1933,
#   280,
#   552,
#   354,
#   793,
#   30,
#   338,
#   449,
#   310,
#   409,
#   342,
#   56,
#   463,
#   403,
#   469,
#   629,
#   543,
#   614,
#   15,
#   3,
#   276,
#   182,
#   403,
#   7,
#   407,
#   706,
#   521,
#   487,
#   318,
#   323,
#   865,
#   178,
#   219,
#   539,
#   1526,
#   475,
#   423,
#   388,
#   209,
#   944,
#   563,
#   555,
#   377,
#   161,
#   245,
#   352,
#   283,
#   133,
#   408,
#   165,
#   509,
#   1085,
#   525,
#   529,
#   38,
#   454,
#   309,
#   258,
#   1,
#   745,
#   296,
#   157,
#   195,
#   225,
#   733,
#   1,
#   317,
#   161,
#   562,
#   416,
#   774,
#   647,
#   357,
#   167,
#   484,
#   271,
#   170,
#   590,
#   233,
#   228,
#   210,
#   258,
#   942,
#   420,
#   649,
#   613,
#   3,
#   487,
#   522,
#   1529,
#   983,
#   310,
#   796,
#   350,
#   774,
#   558,
#   261,
#   765,
#   1301,
#   674,
#   505,
#   613,
#   445,
#   230,
#   650,
#   903,
#   414,
#   411,
#   320,
#   1405,
#   686,
#   801,
#   442,
#   3079,
#   278,
#   631,
#   1092,
#   460,
#   343,
#   651,
#   246,
#   350,
#   161,
#   271,
#   358,
#   399,
#   748,
#   319,
#   663,
#   201,
#   877,
#   1544,
#   1254,
#   307,
#   475,
#   659,
#   245,
#   587,
#   1962,
#   289,
#   932,
#   445,
#   190,
#   672,
#   667,
#   341,
#   549,
#   1058,
#   657,
#   377,
#   968,
#   555,
#   2248,
#   1026,
#   328,
#   397,
#   550,
#   1591,
#   1432,
#   579,
#   278,
#   422,
#   1017,
#   261,
#   597,
#   336,
#   787,
#   254,
#   473,
#   501,
#   712,
#   381,
#   465,
#   644,
#   915,
#   242,
#   431,
#   1460,
#   420,
#   261,
#   541,
#   1278,
#   1185,
#   1997,
#   1275,
#   592,
#   938,
#   322,
#   1513,
#   521,
#   520,
#   498,
#   234,
#   412,
#   616,
#   451,
#   456,
#   465,
#   397,
#   402,
#   517,
#   1092,
#   1657,
#   1910,
#   886,
#   391,
#   801,
#   520,
#   653,
#   1079,
#   1701,
#   908,
#   764,
#   342,
#   7,
#   349,
#   165,
#   1519,
#   158,
#   1154,
#   4624,
#   1,
#   534,
#   2106,
#   1407,
#   730,
#   767,
#   497,
#   331,
#   359,
#   1371,
#   922,
#   552,
#   770,
#   ...]}

# %%
len(infa['id'])
# Out:
# 1542

# %%
import pandas as pd
df = pd.DataFrame(infa)
df.head()
# Out:
#        id text  likes
# 0  101801           9
# 1  101800         139
# 2  101799         113
# 3  101795          44
# 4  101794         176

# %%
df
# Out:
#           id                                               text  likes
# 0     101801                                                         9
# 1     101800                                                       139
# 2     101799                                                       113
# 3     101795                                                        44
# 4     101794                                                       176
# ...      ...                                                ...    ...
# 1537   95767                                                      1655
# 1538   95760           Доброе утро, не забудьте позавтракать ❤️    992
# 1539   95759          пов ты на первом курсе получаешь оценочки   2024
# 1540   95748  препод: читайте методичку там важная информаци...   1124
# 1541   93880                          Говорят там соп доступен)   1577
#
# [1542 rows x 3 columns]

# %% [markdown]
# # Соц-дем пользователей

# %%
# Основные параметры, которые мы хотим получить
fields = 'bdate, city, home_town, sex, education'

# %% [markdown]
# Делаем словарь из списка университетских неофициальных групп

# %%
university_groups = {
     'хайер скул оф мемс' : 'hsemem',
     'Подслушано МГТУ им. Баумана' : 'lovebmstu',
     'мемгу' : 'msuofmems',
     'Подслушано ВШЭ' : 'hse_overheard',
     'Подслушано ИТМО' : 'overhearitmo'
    }

# %%
group_id = 'overhearitmo'

# %%
count = vkDownload('groups.getMembers','group_id=' + group_id)['response']['count']

# %%
count
# Out:
# 20161

# %%
def getGroupMembers(group_id):
    """
        Возвращает список всех пользователей данной группы
        Итерации идут батчами по 1000 пользователей
        
        group_id: string
            идентификатор группы (ссылка)
    """
    
    # Узнаём число запросов, которое надо сделать 
    count = vkDownload('groups.getMembers','group_id=' + group_id)['response']['count']
    
    # выясняем, сколько запросов нам понадобиться
    n = int(np.ceil(count/1000))  
    
    # вектор, где мы будем хранить id пользователей
    members = []     
    
    for i in tqdm_notebook(range(n)): 
        # при помощи метода groups.getMembers получаем пользователей группы
        current_members = vkDownload('groups.getMembers','group_id='+group_id+'&offset='+str(1000*i))
        members.extend(current_members['response']['items'])
        # перед следующим запросом немножко подождем
        time.sleep(0.4)
        
    return members

# %% [markdown]
# Попробуем выкачать группу с минимальным числом подписчиков, возьмем Подслушано ИТМО (для скорости)

# %%
university_groups['Подслушано ИТМО']
# Out:
# 'overhearitmo'

# %%
itmo_members = getGroupMembers(university_groups['Подслушано ИТМО'])
# Out:
# C:\Users\Kseniya\AppData\Local\Temp\ipykernel_5948\1341403498.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(n)):
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
len(itmo_members)
# Out:
# 20161

# %%
itmo_members[:10]
# Out:
# [1127, 2461, 2619, 3768, 4023, 4041, 4579, 5450, 5840, 6371]

# %%
itmo_members
# Out:
# [1127,
#  2461,
#  2619,
#  3768,
#  4023,
#  4041,
#  4579,
#  5450,
#  5840,
#  6371,
#  7047,
#  13592,
#  13753,
#  14195,
#  16944,
#  17192,
#  17338,
#  18994,
#  19866,
#  20047,
#  20498,
#  20923,
#  22158,
#  23532,
#  24147,
#  24961,
#  26253,
#  26380,
#  27460,
#  29031,
#  31563,
#  32059,
#  32866,
#  35320,
#  35646,
#  36264,
#  36788,
#  37435,
#  41033,
#  43101,
#  43421,
#  45610,
#  46012,
#  47314,
#  48817,
#  49082,
#  49264,
#  51142,
#  53366,
#  58801,
#  59089,
#  60056,
#  60692,
#  66191,
#  68686,
#  69693,
#  71029,
#  72058,
#  75340,
#  78801,
#  81784,
#  85806,
#  86002,
#  87014,
#  87982,
#  88186,
#  88416,
#  93238,
#  93528,
#  110703,
#  115715,
#  116602,
#  116665,
#  118291,
#  128698,
#  129921,
#  135556,
#  142301,
#  143646,
#  144725,
#  148065,
#  158752,
#  166625,
#  173104,
#  173550,
#  173582,
#  177350,
#  179245,
#  184757,
#  187288,
#  187989,
#  188178,
#  189470,
#  198206,
#  200848,
#  202395,
#  203209,
#  203846,
#  204272,
#  210925,
#  212956,
#  214300,
#  217487,
#  218298,
#  222771,
#  233307,
#  235676,
#  235702,
#  246481,
#  262371,
#  262432,
#  263929,
#  264428,
#  266442,
#  266525,
#  270170,
#  272432,
#  277510,
#  278261,
#  279325,
#  286089,
#  286223,
#  287979,
#  291640,
#  304098,
#  309565,
#  309651,
#  314566,
#  318821,
#  321614,
#  326589,
#  330611,
#  334124,
#  335952,
#  342687,
#  344349,
#  346777,
#  349090,
#  349448,
#  349465,
#  351282,
#  353889,
#  353896,
#  359249,
#  359375,
#  368762,
#  374746,
#  377601,
#  381327,
#  383387,
#  398359,
#  406931,
#  418043,
#  427603,
#  431301,
#  433597,
#  434152,
#  442465,
#  446351,
#  447899,
#  449965,
#  458778,
#  462798,
#  463216,
#  471790,
#  471977,
#  473831,
#  475624,
#  496476,
#  498437,
#  499723,
#  507824,
#  521130,
#  525363,
#  525538,
#  529083,
#  530131,
#  532012,
#  532131,
#  546612,
#  560684,
#  562969,
#  567891,
#  571593,
#  576645,
#  589674,
#  604293,
#  605044,
#  608128,
#  609132,
#  612670,
#  617885,
#  617912,
#  619456,
#  619813,
#  622417,
#  624369,
#  633074,
#  637494,
#  640363,
#  644859,
#  646270,
#  646689,
#  648151,
#  658707,
#  666196,
#  682937,
#  683694,
#  688908,
#  690955,
#  694162,
#  700325,
#  707881,
#  709737,
#  716491,
#  725683,
#  729615,
#  741252,
#  755042,
#  757559,
#  765194,
#  769957,
#  776458,
#  777681,
#  792157,
#  793328,
#  798517,
#  798747,
#  807071,
#  813732,
#  814315,
#  816224,
#  817770,
#  839639,
#  843513,
#  851024,
#  855071,
#  867704,
#  872217,
#  877174,
#  877887,
#  888406,
#  888825,
#  900905,
#  921590,
#  925142,
#  937203,
#  937671,
#  951269,
#  955371,
#  977753,
#  986308,
#  990272,
#  992501,
#  999059,
#  1000952,
#  1004245,
#  1004554,
#  1007415,
#  1012436,
#  1016197,
#  1020429,
#  1031066,
#  1039636,
#  1040746,
#  1053682,
#  1064335,
#  1076736,
#  1083780,
#  1086806,
#  1091042,
#  1103168,
#  1104369,
#  1118354,
#  1136447,
#  1137321,
#  1140983,
#  1144770,
#  1146742,
#  1152701,
#  1171005,
#  1173051,
#  1173853,
#  1174491,
#  1190538,
#  1200174,
#  1204163,
#  1204709,
#  1210136,
#  1218123,
#  1219966,
#  1223384,
#  1227196,
#  1237285,
#  1254866,
#  1265811,
#  1281485,
#  1283714,
#  1291432,
#  1297310,
#  1303612,
#  1307791,
#  1313596,
#  1319607,
#  1320904,
#  1325420,
#  1330907,
#  1340639,
#  1343525,
#  1352099,
#  1352794,
#  1364099,
#  1364590,
#  1374239,
#  1381168,
#  1397188,
#  1404140,
#  1430247,
#  1446711,
#  1447073,
#  1448264,
#  1456232,
#  1457368,
#  1465739,
#  1474125,
#  1474847,
#  1475301,
#  1475968,
#  1481146,
#  1492934,
#  1502662,
#  1509927,
#  1515487,
#  1527522,
#  1528207,
#  1532945,
#  1551029,
#  1553868,
#  1557273,
#  1577204,
#  1578909,
#  1586405,
#  1587318,
#  1597809,
#  1621636,
#  1623734,
#  1639840,
#  1645724,
#  1659408,
#  1661125,
#  1661650,
#  1667666,
#  1675850,
#  1675930,
#  1680254,
#  1680459,
#  1682949,
#  1698147,
#  1714114,
#  1715514,
#  1716015,
#  1720554,
#  1724327,
#  1727792,
#  1727829,
#  1733776,
#  1734167,
#  1740553,
#  1755354,
#  1766644,
#  1769910,
#  1785383,
#  1788918,
#  1811207,
#  1826909,
#  1830470,
#  1841959,
#  1856322,
#  1856617,
#  1858633,
#  1858742,
#  1859066,
#  1862156,
#  1866166,
#  1866369,
#  1882955,
#  1888791,
#  1895808,
#  1922451,
#  1925147,
#  1938202,
#  1940482,
#  1940886,
#  1941345,
#  1944389,
#  1961471,
#  1964818,
#  1971395,
#  1991425,
#  2010787,
#  2013914,
#  2027544,
#  2040408,
#  2070090,
#  2083019,
#  2084740,
#  2086785,
#  2105977,
#  2106455,
#  2108072,
#  2110629,
#  2116739,
#  2118310,
#  2132243,
#  2136883,
#  2168945,
#  2171379,
#  2176819,
#  2202110,
#  2207952,
#  2227550,
#  2239434,
#  2262105,
#  2278318,
#  2291159,
#  2297840,
#  2303729,
#  2313513,
#  2333863,
#  2348957,
#  2354718,
#  2361964,
#  2368942,
#  2369417,
#  2369508,
#  2372377,
#  2391263,
#  2397858,
#  2406555,
#  2412889,
#  2437367,
#  2437711,
#  2443078,
#  2457032,
#  2474806,
#  2483621,
#  2502698,
#  2522595,
#  2526602,
#  2539988,
#  2542366,
#  2544683,
#  2557729,
#  2558119,
#  2571213,
#  2575003,
#  2576081,
#  2576983,
#  2577092,
#  2590015,
#  2603247,
#  2605134,
#  2608570,
#  2615421,
#  2638971,
#  2642169,
#  2646212,
#  2654941,
#  2665648,
#  2674709,
#  2683854,
#  2698542,
#  2706829,
#  2709519,
#  2717965,
#  2718590,
#  2719217,
#  2725088,
#  2725983,
#  2751368,
#  2764235,
#  2796174,
#  2796703,
#  2805699,
#  2812973,
#  2828366,
#  2831018,
#  2839222,
#  2871978,
#  2875927,
#  2880703,
#  2885190,
#  2900258,
#  8475787,
#  8483774,
#  8496525,
#  8510555,
#  8517252,
#  8518127,
#  8549593,
#  8551187,
#  8552913,
#  8570085,
#  8570528,
#  8575402,
#  8592076,
#  8616539,
#  8622227,
#  8631697,
#  8665125,
#  8671566,
#  8682766,
#  8686147,
#  8705086,
#  8709687,
#  8712277,
#  8723318,
#  8732287,
#  8740859,
#  8741219,
#  8761984,
#  8771691,
#  8789295,
#  8804637,
#  8822696,
#  8827358,
#  8859363,
#  8916853,
#  8957943,
#  8960507,
#  8964785,
#  8970799,
#  9021652,
#  9046451,
#  9055277,
#  9058057,
#  9068904,
#  9077659,
#  9080524,
#  9090505,
#  9108827,
#  9110212,
#  9114242,
#  9136972,
#  9150315,
#  9155270,
#  9181158,
#  9186678,
#  9203161,
#  9208780,
#  9210014,
#  9227387,
#  9228013,
#  9247090,
#  9260443,
#  9282451,
#  9290501,
#  9293422,
#  9295803,
#  9306786,
#  9307003,
#  9369070,
#  ...]

# %% [markdown]
# Прекрасно, получили список из 20161 идентификатора пользователей, подписанных на группу Послушано ИТМО. Всех остальных подписчиков можно выгрузить аналогично.

# %%
# Цикл для выгрузки всех участников групп
# Выкачиваем членов каждой группы 

university_people = {}
for university, group_id in university_groups.items():
    university_people[university] = getGroupMembers(group_id)

# Сохраняем словарик с id пользователей
with open('university_people', 'wb') as f:
    pickle.dump(university_people, f)
# Out:
# C:\Users\Kseniya\AppData\Local\Temp\ipykernel_5948\1341403498.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(n)):
#   0%|          | 0/89 [00:00<?, ?it/s]
#   0%|          | 0/43 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/49 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]

# %% [markdown]
# Когда нужно подгрузить готовый словарь id пользователей

# %%
# Подгружаем словарь с пользователями
#with open('candidate_people', 'rb') as f:
#candidate_people = pickle.load(f)

# %% [markdown]
# Посмотрим на число подписчиков

# %%
for university, people in university_people.items():
    print("Группа университета: {}, число подписчиков: {}".format(university, len(people)))
# Out:
# Группа университета: хайер скул оф мемс, число подписчиков: 88247
# Группа университета: Подслушано МГТУ им. Баумана, число подписчиков: 42033
# Группа университета: мемгу, число подписчиков: 49415
# Группа университета: Подслушано ВШЭ, число подписчиков: 48547
# Группа университета: Подслушано ИТМО, число подписчиков: 20161

# %%
count = sum(university_people.values(), [])
count
# Out:
# [1257,
#  1389,
#  2050,
#  2932,
#  4913,
#  6559,
#  8612,
#  9147,
#  9804,
#  10615,
#  10942,
#  17365,
#  29658,
#  30166,
#  35374,
#  41372,
#  42159,
#  42495,
#  43668,
#  50385,
#  53771,
#  56572,
#  56613,
#  62335,
#  65433,
#  65995,
#  66203,
#  66778,
#  68046,
#  71090,
#  71426,
#  71885,
#  71947,
#  74008,
#  75791,
#  81206,
#  84894,
#  85414,
#  91221,
#  93245,
#  97723,
#  100453,
#  111145,
#  111195,
#  111952,
#  123696,
#  127387,
#  129910,
#  131984,
#  133910,
#  136773,
#  139259,
#  141498,
#  142252,
#  151817,
#  151979,
#  157555,
#  158814,
#  175846,
#  179627,
#  192662,
#  198166,
#  201219,
#  225701,
#  229145,
#  229578,
#  230307,
#  231043,
#  236730,
#  240199,
#  241907,
#  249661,
#  258980,
#  266700,
#  272832,
#  283162,
#  287568,
#  291662,
#  322193,
#  324578,
#  326105,
#  335913,
#  353634,
#  355081,
#  364844,
#  385594,
#  386542,
#  396809,
#  398266,
#  398616,
#  416407,
#  431834,
#  442103,
#  443897,
#  445760,
#  453778,
#  455134,
#  469854,
#  483633,
#  496047,
#  502620,
#  504092,
#  511020,
#  512776,
#  517992,
#  522144,
#  526190,
#  529919,
#  536684,
#  543725,
#  552502,
#  555692,
#  558683,
#  568641,
#  569437,
#  577425,
#  579285,
#  586500,
#  602387,
#  608713,
#  614415,
#  622387,
#  624566,
#  631854,
#  638334,
#  640287,
#  651325,
#  661043,
#  664644,
#  690011,
#  693390,
#  716033,
#  721446,
#  721939,
#  731713,
#  740914,
#  745517,
#  748626,
#  751431,
#  753824,
#  755233,
#  759689,
#  764354,
#  770885,
#  806597,
#  807118,
#  814734,
#  817304,
#  846839,
#  854347,
#  855620,
#  858691,
#  865734,
#  870813,
#  883931,
#  900478,
#  903307,
#  905155,
#  916615,
#  920855,
#  922147,
#  922429,
#  927160,
#  928852,
#  939706,
#  942887,
#  966741,
#  982692,
#  994266,
#  1000161,
#  1009029,
#  1015282,
#  1026960,
#  1027981,
#  1028119,
#  1030517,
#  1036786,
#  1049960,
#  1052054,
#  1057921,
#  1070952,
#  1081845,
#  1084180,
#  1086719,
#  1090153,
#  1092577,
#  1093551,
#  1096126,
#  1106427,
#  1145949,
#  1176330,
#  1179913,
#  1190088,
#  1218384,
#  1261723,
#  1272440,
#  1273134,
#  1274466,
#  1286810,
#  1288002,
#  1299663,
#  1303824,
#  1320605,
#  1325370,
#  1349748,
#  1350377,
#  1351828,
#  1357592,
#  1366447,
#  1380525,
#  1396880,
#  1443250,
#  1447493,
#  1468648,
#  1481519,
#  1493920,
#  1500291,
#  1502369,
#  1510825,
#  1511262,
#  1519480,
#  1524839,
#  1540203,
#  1546616,
#  1585315,
#  1590017,
#  1593744,
#  1594400,
#  1608291,
#  1621202,
#  1622737,
#  1637199,
#  1642210,
#  1644847,
#  1647292,
#  1648069,
#  1665081,
#  1667372,
#  1687066,
#  1689366,
#  1701917,
#  1731153,
#  1735893,
#  1736111,
#  1754681,
#  1764982,
#  1769281,
#  1778109,
#  1814304,
#  1815814,
#  1849681,
#  1860949,
#  1867684,
#  1886646,
#  1892411,
#  1894539,
#  1896793,
#  1896907,
#  1917861,
#  1920040,
#  1943597,
#  1945696,
#  1969351,
#  1971021,
#  1971987,
#  1973963,
#  1975043,
#  1978350,
#  1993078,
#  2009648,
#  2013657,
#  2041360,
#  2042341,
#  2056909,
#  2057807,
#  2058016,
#  2059991,
#  2065722,
#  2067727,
#  2072056,
#  2079378,
#  2099966,
#  2118399,
#  2125667,
#  2133268,
#  2143549,
#  2144738,
#  2161200,
#  2163460,
#  2167859,
#  2170802,
#  2177279,
#  2188369,
#  2197088,
#  2205237,
#  8503066,
#  8504938,
#  8517526,
#  8541422,
#  8545234,
#  8546075,
#  8553504,
#  8554778,
#  8573422,
#  8575002,
#  8580932,
#  8591083,
#  8596253,
#  8611391,
#  8613198,
#  8647610,
#  8648346,
#  8651124,
#  8653441,
#  8654175,
#  8654725,
#  8669101,
#  8669306,
#  8673376,
#  8677092,
#  8677108,
#  8679846,
#  8701719,
#  8705086,
#  8729122,
#  8731758,
#  8732932,
#  8733160,
#  8735570,
#  8741356,
#  8743328,
#  8761019,
#  8761370,
#  8774362,
#  8789874,
#  8793641,
#  8797268,
#  8845682,
#  8854154,
#  8855031,
#  8865825,
#  8882990,
#  ...]

# %% [markdown]
#  также составим список из уникальных пользователей и посмотрим, сколько их у нас всего

# %%
# объединяем всех подписчиков в один лист
unique_people = sum(university_people.values(), [])
# берем только уникальных людей
unique_people = list(set(unique_people))

len(unique_people)
# Out:
# 201843

# %% [markdown]
# Отлично, 201842 уникальных пользователей, подписанных на неофициальные группы, у нас есть. Теперь скачаем немножко соцдема по этим людям.

# %% [markdown]
# Для выкачки соц-дема будем использовать метод `users.get`. За раз можно скачать информацию о 100 пользователях. Если на запрос будет уходить секунда, то скачка соц-дема займет около 1 часа.

# %%
round(201842/100/60/60, 2)
# Out:
# 0.56

# %% [markdown]
# Для пробы пера возьмем первых (по дате регистрации в вк) 10 человек, подписанных на мемгу

# %%
msuofmems = university_people['мемгу'][:10]
# объединяем лист с int в строку
msuofmems = ','.join([str(user) for user in msuofmems])

# %%
vkDownload('users.get', 'user_ids={}&fields={}'.format(msuofmems, fields))
# Out:
# {'response': [{'id': 3226,
#    'bdate': '21.6.1988',
#    'city': {'id': 1937764, 'title': 'Paris'},
#    'sex': 1,
#    'first_name': 'Ekaterina',
#    'last_name': 'Besse',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 7441,
#    'bdate': '31.12.1980',
#    'city': {'id': 1, 'title': 'Москва'},
#    'university': 1,
#    'university_name': 'СПбГУ',
#    'faculty': 15,
#    'faculty_name': 'Филологический факультет',
#    'graduation': 2004,
#    'education_form': 'Очное отделение',
#    'education_status': 'Выпускница (специалист)',
#    'home_town': 'Санкт-Петербург',
#    'sex': 1,
#    'first_name': 'Лидия',
#    'last_name': 'Кузнецова',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 8837,
#    'bdate': '7.8',
#    'city': {'id': 1, 'title': 'Москва'},
#    'sex': 2,
#    'first_name': 'Илья',
#    'last_name': 'Кудряшов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 15572,
#    'bdate': '27.11.1990',
#    'sex': 2,
#    'first_name': 'Шамиль',
#    'last_name': 'Джабоев',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 15762,
#    'bdate': '22.2',
#    'city': {'id': 1, 'title': 'Москва'},
#    'sex': 1,
#    'first_name': 'Anastasia',
#    'last_name': 'Kuzmicheva',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 17365,
#    'bdate': '29.4',
#    'city': {'id': 1, 'title': 'Москва'},
#    'sex': 2,
#    'first_name': 'Владимир',
#    'last_name': 'Рожнов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 19980,
#    'bdate': '15.1.1981',
#    'city': {'id': 1, 'title': 'Москва'},
#    'university': 2,
#    'university_name': 'МГУ',
#    'faculty': 39,
#    'faculty_name': 'Филологический',
#    'graduation': 2002,
#    'education_form': 'Очное отделение',
#    'education_status': 'Кандидат наук',
#    'home_town': 'Москва',
#    'sex': 1,
#    'first_name': 'Инна',
#    'last_name': 'Фомина',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 21582,
#    'bdate': '13.12.1986',
#    'city': {'id': 1519, 'title': 'Гатчина'},
#    'sex': 2,
#    'first_name': 'Михаил',
#    'last_name': 'Голубев',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 30392,
#    'bdate': '26.2.1988',
#    'city': {'id': 1, 'title': 'Москва'},
#    'university': 2,
#    'university_name': 'МГУ',
#    'faculty': 28,
#    'faculty_name': 'Иностранных языков и регионоведения',
#    'graduation': 2009,
#    'education_form': 'Очное отделение',
#    'education_status': 'Выпускница (специалист)',
#    'home_town': 'Москва',
#    'sex': 1,
#    'first_name': 'Марина',
#    'last_name': 'Юровская',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 33078,
#    'bdate': '22.7',
#    'city': {'id': 1, 'title': 'Москва'},
#    'university': 0,
#    'university_name': '',
#    'faculty': 0,
#    'faculty_name': '',
#    'graduation': 0,
#    'home_town': 'москва',
#    'sex': 1,
#    'first_name': 'Катя',
#    'last_name': 'Хаткина',
#    'can_access_closed': True,
#    'is_closed': False}]}

# %% [markdown]
# Обернем сбор информации по юзерам в функцию

# %%
def getUserInformation():
    """
        Возвращает словарь с выгруженными социально-демографическими данными 
        по всем пользователям, подписанным на группы
    """
    
    # инициализируем пустой словарь, где будут хранитсья пользователи с их соцдемом
    university_people_information = {}
    # проходимся по всем кандидатам
    for university, people in university_people.items():
        # текущий список пользователей с соц-демом
        current_info = []
        #посчитаем число пользователей для группы
        count = len(people)
        # Выяснили число запросов
        n = int(np.ceil(count/500))  
        
        for i in tqdm_notebook(range(n)):
            # берем текущий срез подписчиков
            ids = people[i*500:(i+1)*500]
            ids = ','.join([str(user) for user in ids])
            # выгружаем их и берем данные
            info = vkDownload('users.get','user_ids={}&fields={}'.format(ids, fields))
            info = info['response']
            # записываем в текущий лист
            current_info.extend(info)
            # ждем перед следующим запросом
            time.sleep(0.4)
        
        # записываем в финальный словарь
        university_people_information[university] = current_info
    
    return university_people_information

# %%
university_people_information = getUserInformation()
# Out:
# C:\Users\Kseniya\AppData\Local\Temp\ipykernel_5948\1507951425.py:18: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(n)):
#   0%|          | 0/177 [00:00<?, ?it/s]
#   0%|          | 0/85 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
#   0%|          | 0/41 [00:00<?, ?it/s]

# %%
#спрячем данные в дамп pickle
with open('university_people_information', 'wb') as f:
     pickle.dump(university_people_information, f)

#если нужно открыть дамп из pickle
#with open('university_people_information', 'rb') as f:
    #candidate_people_information = pickle.load(f)

# %% [markdown]
# А теперь преобразуем полученный словарь в удобный датафрейм для последующей работы

# %%
# инициализируем датафрейм
people_information_df = pd.DataFrame()

# идем по всем кандидатам и соц-дему их подписчиков
for university, people in university_people_information.items():
    # преобразуем в словарь в датафрейм
    df = pd.DataFrame(people)
    # добавляем столбец с городом
    df['city'] = df.city.apply(lambda x: x['title'] if x is not np.nan else np.nan)
    # добавляем столбец с городом
    df['university'] = university
    # добавляем преобразованный датафрейм к финальному
    people_information_df = people_information_df.append(df, ignore_index=True)
# Out:
# C:\Users\Kseniya\AppData\Local\Temp\ipykernel_5948\3590913831.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   people_information_df = people_information_df.append(df, ignore_index=True)
# C:\Users\Kseniya\AppData\Local\Temp\ipykernel_5948\3590913831.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   people_information_df = people_information_df.append(df, ignore_index=True)
# C:\Users\Kseniya\AppData\Local\Temp\ipykernel_5948\3590913831.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   people_information_df = people_information_df.append(df, ignore_index=True)
# C:\Users\Kseniya\AppData\Local\Temp\ipykernel_5948\3590913831.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   people_information_df = people_information_df.append(df, ignore_index=True)
# C:\Users\Kseniya\AppData\Local\Temp\ipykernel_5948\3590913831.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   people_information_df = people_information_df.append(df, ignore_index=True)

# %%
people_information_df
# Out:
#                 id       bdate             city  sex first_name   last_name  \
# 0             1257  19.10.1989           Sliema    2       Олег    Уржумцев
# 1             1389  24.12.1986  Нижний Новгород    2       Иван  Безбородый
# 2             2050        27.4  Санкт-Петербург    1       Катя    Лебедева
# 3             2932         NaN  Санкт-Петербург    2     Кирилл    Когортов
# 4             4913    5.2.1984  Санкт-Петербург    1     Марина    Секачева
# ...            ...         ...              ...  ...        ...         ...
# 248398  1026429726   27.8.1995              NaN    2      Захар    Литвинов
# 248399  1029386637   19.2.2011              NaN    1      Олеся      Работа
# 248400  1029757427    9.2.2006              NaN    2    Василий    Солдатов
# 248401  1030885157         NaN              NaN    2      Majid           A
# 248402  1031810469   11.3.2003              NaN    1       Lina        Milo
#
#         can_access_closed  is_closed          university  \
# 0                    True      False  хайер скул оф мемс
# 1                   False       True  хайер скул оф мемс
# 2                    True      False  хайер скул оф мемс
# 3                   False       True  хайер скул оф мемс
# 4                   False       True  хайер скул оф мемс
# ...                   ...        ...                 ...
# 248398              False       True     Подслушано ИТМО
# 248399               True      False     Подслушано ИТМО
# 248400              False       True     Подслушано ИТМО
# 248401               True      False     Подслушано ИТМО
# 248402               True      False     Подслушано ИТМО
#
#                   university_name  faculty faculty_name  graduation  \
# 0                             NaN      NaN          NaN         NaN
# 1                             NaN      NaN          NaN         NaN
# 2       НИУ ВШЭ - Санкт-Петербург      0.0                   2012.0
# 3                             NaN      NaN          NaN         NaN
# 4                             NaN      NaN          NaN         NaN
# ...                           ...      ...          ...         ...
# 248398                        NaN      NaN          NaN         NaN
# 248399                        NaN      NaN          NaN         NaN
# 248400                        NaN      NaN          NaN         NaN
# 248401                        NaN      NaN          NaN         NaN
# 248402                                 0.0                      0.0
#
#         home_town education_form education_status deactivated
# 0             NaN            NaN              NaN         NaN
# 1             NaN            NaN              NaN         NaN
# 2       Ленинград            NaN              NaN         NaN
# 3             NaN            NaN              NaN         NaN
# 4             NaN            NaN              NaN         NaN
# ...           ...            ...              ...         ...
# 248398        NaN            NaN              NaN      banned
# 248399        NaN            NaN              NaN      banned
# 248400        NaN            NaN              NaN      banned
# 248401        NaN            NaN              NaN         NaN
# 248402                       NaN              NaN         NaN
#
# [248403 rows x 17 columns]

# %%
people_information_df.shape
# Out:
# (248403, 17)

# %%
people_information_df.to_csv('university-nonofficial.csv', sep=',')

# %%
people_information_df = pd.read_csv('university-nonofficial.csv')

# %%
people_information_df
# Out:
#         Unnamed: 0          id       bdate             city  sex first_name  \
# 0                0        1257  19.10.1989           Sliema    2       Олег
# 1                1        1389  24.12.1986  Нижний Новгород    2       Иван
# 2                2        2050        27.4  Санкт-Петербург    1       Катя
# 3                3        2932         NaN  Санкт-Петербург    2     Кирилл
# 4                4        4913    5.2.1984  Санкт-Петербург    1     Марина
# ...            ...         ...         ...              ...  ...        ...
# 248398      248398  1026429726   27.8.1995              NaN    2      Захар
# 248399      248399  1029386637   19.2.2011              NaN    1      Олеся
# 248400      248400  1029757427    9.2.2006              NaN    2    Василий
# 248401      248401  1030885157         NaN              NaN    2      Majid
# 248402      248402  1031810469   11.3.2003              NaN    1       Lina
#
#          last_name  can_access_closed  is_closed          university  \
# 0         Уржумцев               True      False  хайер скул оф мемс
# 1       Безбородый              False       True  хайер скул оф мемс
# 2         Лебедева               True      False  хайер скул оф мемс
# 3         Когортов              False       True  хайер скул оф мемс
# 4         Секачева              False       True  хайер скул оф мемс
# ...            ...                ...        ...                 ...
# 248398    Литвинов              False       True     Подслушано ИТМО
# 248399      Работа               True      False     Подслушано ИТМО
# 248400    Солдатов              False       True     Подслушано ИТМО
# 248401           A               True      False     Подслушано ИТМО
# 248402        Milo               True      False     Подслушано ИТМО
#
#                   university_name  faculty faculty_name  graduation  \
# 0                             NaN      NaN          NaN         NaN
# 1                             NaN      NaN          NaN         NaN
# 2       НИУ ВШЭ - Санкт-Петербург      0.0          NaN      2012.0
# 3                             NaN      NaN          NaN         NaN
# 4                             NaN      NaN          NaN         NaN
# ...                           ...      ...          ...         ...
# 248398                        NaN      NaN          NaN         NaN
# 248399                        NaN      NaN          NaN         NaN
# 248400                        NaN      NaN          NaN         NaN
# 248401                        NaN      NaN          NaN         NaN
# 248402                        NaN      0.0          NaN         0.0
#
#         home_town education_form education_status deactivated
# 0             NaN            NaN              NaN         NaN
# 1             NaN            NaN              NaN         NaN
# 2       Ленинград            NaN              NaN         NaN
# 3             NaN            NaN              NaN         NaN
# 4             NaN            NaN              NaN         NaN
# ...           ...            ...              ...         ...
# 248398        NaN            NaN              NaN      banned
# 248399        NaN            NaN              NaN      banned
# 248400        NaN            NaN              NaN      banned
# 248401        NaN            NaN              NaN         NaN
# 248402        NaN            NaN              NaN         NaN
#
# [248403 rows x 18 columns]

# %% [markdown]
# ## Преобразование данных

# %% [markdown]
# Меняем значения для гендера (переменная - sex)

# %%
#Способ 1. Текст
people_information_df['sex'] = np.where(people_information_df['sex']==1, 'Female', 'Male')

# %%
people_information_df['sex']
# Out:
# 0           Male
# 1           Male
# 2         Female
# 3           Male
# 4         Female
#            ...
# 248398      Male
# 248399    Female
# 248400      Male
# 248401      Male
# 248402    Female
# Name: sex, Length: 248403, dtype: object

# %%
#Способ 2. Булевы значения
people_information_df['sex_female'] = np.where(people_information_df['sex']==1, True, False)

# %%
#Способ 3. Метод replace
people_information_df['sex_female'] = np.where(people_information_df['sex']==1, True, False)

# %%
# Способ 4. Метод map
people_information_df['sex'] = people_information_df['sex'].map({1:'Female',2:'Male'})

# %%
#удаление лишних или мусорных столбцов
#people_information_df = people_information_df.drop(['sex_female'], axis=1)
#people_information_df

# %%
people_information_df
# Out:
#         Unnamed: 0          id       bdate             city  sex first_name  \
# 0                0        1257  19.10.1989           Sliema  NaN       Олег
# 1                1        1389  24.12.1986  Нижний Новгород  NaN       Иван
# 2                2        2050        27.4  Санкт-Петербург  NaN       Катя
# 3                3        2932         NaN  Санкт-Петербург  NaN     Кирилл
# 4                4        4913    5.2.1984  Санкт-Петербург  NaN     Марина
# ...            ...         ...         ...              ...  ...        ...
# 248398      248398  1026429726   27.8.1995              NaN  NaN      Захар
# 248399      248399  1029386637   19.2.2011              NaN  NaN      Олеся
# 248400      248400  1029757427    9.2.2006              NaN  NaN    Василий
# 248401      248401  1030885157         NaN              NaN  NaN      Majid
# 248402      248402  1031810469   11.3.2003              NaN  NaN       Lina
#
#          last_name  can_access_closed  is_closed          university  \
# 0         Уржумцев               True      False  хайер скул оф мемс
# 1       Безбородый              False       True  хайер скул оф мемс
# 2         Лебедева               True      False  хайер скул оф мемс
# 3         Когортов              False       True  хайер скул оф мемс
# 4         Секачева              False       True  хайер скул оф мемс
# ...            ...                ...        ...                 ...
# 248398    Литвинов              False       True     Подслушано ИТМО
# 248399      Работа               True      False     Подслушано ИТМО
# 248400    Солдатов              False       True     Подслушано ИТМО
# 248401           A               True      False     Подслушано ИТМО
# 248402        Milo               True      False     Подслушано ИТМО
#
#                   university_name  faculty faculty_name  graduation  \
# 0                             NaN      NaN          NaN         NaN
# 1                             NaN      NaN          NaN         NaN
# 2       НИУ ВШЭ - Санкт-Петербург      0.0          NaN      2012.0
# 3                             NaN      NaN          NaN         NaN
# 4                             NaN      NaN          NaN         NaN
# ...                           ...      ...          ...         ...
# 248398                        NaN      NaN          NaN         NaN
# 248399                        NaN      NaN          NaN         NaN
# 248400                        NaN      NaN          NaN         NaN
# 248401                        NaN      NaN          NaN         NaN
# 248402                        NaN      0.0          NaN         0.0
#
#         home_town education_form education_status deactivated  sex_female
# 0             NaN            NaN              NaN         NaN       False
# 1             NaN            NaN              NaN         NaN       False
# 2       Ленинград            NaN              NaN         NaN       False
# 3             NaN            NaN              NaN         NaN       False
# 4             NaN            NaN              NaN         NaN       False
# ...           ...            ...              ...         ...         ...
# 248398        NaN            NaN              NaN      banned       False
# 248399        NaN            NaN              NaN      banned       False
# 248400        NaN            NaN              NaN      banned       False
# 248401        NaN            NaN              NaN         NaN       False
# 248402        NaN            NaN              NaN         NaN       False
#
# [248403 rows x 19 columns]

# %%
people_information_df['university'].unique()
# Out:
# array(['хайер скул оф мемс', 'Подслушано МГТУ им. Баумана', 'мемгу',
#        'Подслушано ВШЭ', 'Подслушано ИТМО'], dtype=object)

# %% [markdown]
# ## Определение возвраста пользователя по дате рождения

# %% [markdown]
# Дата рождения пользователей указана в разных форматах: не указана открыто (NaN), указаны день и месяц без года, указано польность дд.мм.гг. Для нормализации данных по этой переменной нам проще всего пойти путм разделения текст bdate на три столбца по символу "."

# %%
people_information_df['bdate'].str.split('.', expand=True)
#агрумент expand=True значит создание новых столбцов из разденного
# Out:
#           0    1     2
# 0        19   10  1989
# 1        24   12  1986
# 2        27    4  None
# 3       NaN  NaN   NaN
# 4         5    2  1984
# ...     ...  ...   ...
# 248398   27    8  1995
# 248399   19    2  2011
# 248400    9    2  2006
# 248401  NaN  NaN   NaN
# 248402   11    3  2003
#
# [248403 rows x 3 columns]

# %% [markdown]
# пока мы никак не сохранили результат, а просто посмотрели, как это выглядит

# %% [markdown]
# Создаем вспомогательный датафрейм для извлечения информации о количестве лет пользователя, чтобы сохранить исходный датафрейм

# %%
df_bdate = people_information_df

# %%
#датафрейм df_ нужен для временного хранения данных о дате рождения в разных столбцах
df_ = df_bdate['bdate'].str.split('.', expand=True)

# %%
#объединяем два датарфрейиа по index
df_bdate = pd.concat([df_bdate, df_], axis=1)

# %%
df_bdate
# Out:
#         Unnamed: 0          id       bdate             city  sex first_name  \
# 0                0        1257  19.10.1989           Sliema  NaN       Олег
# 1                1        1389  24.12.1986  Нижний Новгород  NaN       Иван
# 2                2        2050        27.4  Санкт-Петербург  NaN       Катя
# 3                3        2932         NaN  Санкт-Петербург  NaN     Кирилл
# 4                4        4913    5.2.1984  Санкт-Петербург  NaN     Марина
# ...            ...         ...         ...              ...  ...        ...
# 248398      248398  1026429726   27.8.1995              NaN  NaN      Захар
# 248399      248399  1029386637   19.2.2011              NaN  NaN      Олеся
# 248400      248400  1029757427    9.2.2006              NaN  NaN    Василий
# 248401      248401  1030885157         NaN              NaN  NaN      Majid
# 248402      248402  1031810469   11.3.2003              NaN  NaN       Lina
#
#          last_name  can_access_closed  is_closed          university  ...  \
# 0         Уржумцев               True      False  хайер скул оф мемс  ...
# 1       Безбородый              False       True  хайер скул оф мемс  ...
# 2         Лебедева               True      False  хайер скул оф мемс  ...
# 3         Когортов              False       True  хайер скул оф мемс  ...
# 4         Секачева              False       True  хайер скул оф мемс  ...
# ...            ...                ...        ...                 ...  ...
# 248398    Литвинов              False       True     Подслушано ИТМО  ...
# 248399      Работа               True      False     Подслушано ИТМО  ...
# 248400    Солдатов              False       True     Подслушано ИТМО  ...
# 248401           A               True      False     Подслушано ИТМО  ...
# 248402        Milo               True      False     Подслушано ИТМО  ...
#
#        faculty_name  graduation  home_town  education_form education_status  \
# 0               NaN         NaN        NaN             NaN              NaN
# 1               NaN         NaN        NaN             NaN              NaN
# 2               NaN      2012.0  Ленинград             NaN              NaN
# 3               NaN         NaN        NaN             NaN              NaN
# 4               NaN         NaN        NaN             NaN              NaN
# ...             ...         ...        ...             ...              ...
# 248398          NaN         NaN        NaN             NaN              NaN
# 248399          NaN         NaN        NaN             NaN              NaN
# 248400          NaN         NaN        NaN             NaN              NaN
# 248401          NaN         NaN        NaN             NaN              NaN
# 248402          NaN         0.0        NaN             NaN              NaN
#
#        deactivated sex_female    0    1     2
# 0              NaN      False   19   10  1989
# 1              NaN      False   24   12  1986
# 2              NaN      False   27    4  None
# 3              NaN      False  NaN  NaN   NaN
# 4              NaN      False    5    2  1984
# ...            ...        ...  ...  ...   ...
# 248398      banned      False   27    8  1995
# 248399      banned      False   19    2  2011
# 248400      banned      False    9    2  2006
# 248401         NaN      False  NaN  NaN   NaN
# 248402         NaN      False   11    3  2003
#
# [248403 rows x 22 columns]

# %%
df_bdate = df_bdate.rename(columns={0: 'day_bdate', 1: 'month_bdate', 2: 'year_bdate'})

# %%
df_bdate
# Out:
#         Unnamed: 0          id       bdate             city  sex first_name  \
# 0                0        1257  19.10.1989           Sliema  NaN       Олег
# 1                1        1389  24.12.1986  Нижний Новгород  NaN       Иван
# 2                2        2050        27.4  Санкт-Петербург  NaN       Катя
# 3                3        2932         NaN  Санкт-Петербург  NaN     Кирилл
# 4                4        4913    5.2.1984  Санкт-Петербург  NaN     Марина
# ...            ...         ...         ...              ...  ...        ...
# 248398      248398  1026429726   27.8.1995              NaN  NaN      Захар
# 248399      248399  1029386637   19.2.2011              NaN  NaN      Олеся
# 248400      248400  1029757427    9.2.2006              NaN  NaN    Василий
# 248401      248401  1030885157         NaN              NaN  NaN      Majid
# 248402      248402  1031810469   11.3.2003              NaN  NaN       Lina
#
#          last_name  can_access_closed  is_closed          university  ...  \
# 0         Уржумцев               True      False  хайер скул оф мемс  ...
# 1       Безбородый              False       True  хайер скул оф мемс  ...
# 2         Лебедева               True      False  хайер скул оф мемс  ...
# 3         Когортов              False       True  хайер скул оф мемс  ...
# 4         Секачева              False       True  хайер скул оф мемс  ...
# ...            ...                ...        ...                 ...  ...
# 248398    Литвинов              False       True     Подслушано ИТМО  ...
# 248399      Работа               True      False     Подслушано ИТМО  ...
# 248400    Солдатов              False       True     Подслушано ИТМО  ...
# 248401           A               True      False     Подслушано ИТМО  ...
# 248402        Milo               True      False     Подслушано ИТМО  ...
#
#        faculty_name  graduation  home_town  education_form education_status  \
# 0               NaN         NaN        NaN             NaN              NaN
# 1               NaN         NaN        NaN             NaN              NaN
# 2               NaN      2012.0  Ленинград             NaN              NaN
# 3               NaN         NaN        NaN             NaN              NaN
# 4               NaN         NaN        NaN             NaN              NaN
# ...             ...         ...        ...             ...              ...
# 248398          NaN         NaN        NaN             NaN              NaN
# 248399          NaN         NaN        NaN             NaN              NaN
# 248400          NaN         NaN        NaN             NaN              NaN
# 248401          NaN         NaN        NaN             NaN              NaN
# 248402          NaN         0.0        NaN             NaN              NaN
#
#        deactivated sex_female day_bdate  month_bdate year_bdate
# 0              NaN      False        19           10       1989
# 1              NaN      False        24           12       1986
# 2              NaN      False        27            4       None
# 3              NaN      False       NaN          NaN        NaN
# 4              NaN      False         5            2       1984
# ...            ...        ...       ...          ...        ...
# 248398      banned      False        27            8       1995
# 248399      banned      False        19            2       2011
# 248400      banned      False         9            2       2006
# 248401         NaN      False       NaN          NaN        NaN
# 248402         NaN      False        11            3       2003
#
# [248403 rows x 22 columns]

# %%
#Фильтруем аудиторию по признаку открытости страницы
#df_bdate = df_bdate.loc[((df_bdate['can_access_closed'] == True))]

# %%
#удаляем столбцы с днем и месяцем рождения, нам нужен только год
df_bdate = df_bdate.drop(['day_bdate', 'month_bdate'], axis=1)

# %%
df_bdate.isnull().sum()
# Out:
# Unnamed: 0                0
# id                        0
# bdate                 42942
# city                  82590
# sex                  248403
# first_name                0
# last_name              9063
# can_access_closed         0
# is_closed                 0
# university                0
# university_name      192965
# faculty              169330
# faculty_name         210781
# graduation           169330
# home_town            205437
# education_form       229206
# education_status     227205
# deactivated          229631
# sex_female                0
# year_bdate           154572
# dtype: int64

# %% [markdown]
# Удаляем все строки, если в столбце year_bdate NaN

# %%
df_bdate = df_bdate.dropna(subset=['year_bdate'])

# %%
df_bdate
# Out:
#         Unnamed: 0          id       bdate             city  sex first_name  \
# 0                0        1257  19.10.1989           Sliema  NaN       Олег
# 1                1        1389  24.12.1986  Нижний Новгород  NaN       Иван
# 4                4        4913    5.2.1984  Санкт-Петербург  NaN     Марина
# 5                5        6559   13.1.1984          Барнаул  NaN      Федор
# 6                6        8612    1.4.1996           Phuket  NaN  Анастасия
# ...            ...         ...         ...              ...  ...        ...
# 248397      248397  1026426427   25.4.2001              NaN  NaN     Андрей
# 248398      248398  1026429726   27.8.1995              NaN  NaN      Захар
# 248399      248399  1029386637   19.2.2011              NaN  NaN      Олеся
# 248400      248400  1029757427    9.2.2006              NaN  NaN    Василий
# 248402      248402  1031810469   11.3.2003              NaN  NaN       Lina
#
#          last_name  can_access_closed  is_closed          university  \
# 0         Уржумцев               True      False  хайер скул оф мемс
# 1       Безбородый              False       True  хайер скул оф мемс
# 4         Секачева              False       True  хайер скул оф мемс
# 5         Клименко               True      False  хайер скул оф мемс
# 6       Оболенская               True      False  хайер скул оф мемс
# ...            ...                ...        ...                 ...
# 248397    Барсуков              False       True     Подслушано ИТМО
# 248398    Литвинов              False       True     Подслушано ИТМО
# 248399      Работа               True      False     Подслушано ИТМО
# 248400    Солдатов              False       True     Подслушано ИТМО
# 248402        Milo               True      False     Подслушано ИТМО
#
#        university_name  faculty  \
# 0                  NaN      NaN
# 1                  NaN      NaN
# 4                  NaN      NaN
# 5                АлтГУ   3238.0
# 6       СПбГЭТУ «ЛЭТИ»    324.0
# ...                ...      ...
# 248397             NaN      NaN
# 248398             NaN      NaN
# 248399             NaN      NaN
# 248400             NaN      NaN
# 248402             NaN      0.0
#
#                                              faculty_name  graduation  \
# 0                                                     NaN         NaN
# 1                                                     NaN         NaN
# 4                                                     NaN         NaN
# 5                                          Филологический      2009.0
# 6       Компьютерных технологий и информатики (ФКТИ, Ф...      2004.0
# ...                                                   ...         ...
# 248397                                                NaN         NaN
# 248398                                                NaN         NaN
# 248399                                                NaN         NaN
# 248400                                                NaN         NaN
# 248402                                                NaN         0.0
#
#                         home_town   education_form        education_status  \
# 0                             NaN              NaN                     NaN
# 1                             NaN              NaN                     NaN
# 4                             NaN              NaN                     NaN
# 5       Барнаул - столица МИРА!!!  Очное отделение  Выпускник (специалист)
# 6                             NaN  Очное отделение    Выпускница (магистр)
# ...                           ...              ...                     ...
# 248397                        NaN              NaN                     NaN
# 248398                        NaN              NaN                     NaN
# 248399                        NaN              NaN                     NaN
# 248400                        NaN              NaN                     NaN
# 248402                        NaN              NaN                     NaN
#
#        deactivated  sex_female year_bdate
# 0              NaN       False       1989
# 1              NaN       False       1986
# 4              NaN       False       1984
# 5              NaN       False       1984
# 6              NaN       False       1996
# ...            ...         ...        ...
# 248397      banned       False       2001
# 248398      banned       False       1995
# 248399      banned       False       2011
# 248400      banned       False       2006
# 248402         NaN       False       2003
#
# [93831 rows x 20 columns]

# %%
#df_bdate['age'] = year_today - df_bdate['year_bdate'].astype (int)

# %%
df_bdate.dtypes

# %%
df_bdate

# %% [markdown]
# Для вычисления возраста нам нужно от текущего года вычесть год рождения. Для этого переменная year_bdate должна быть числом

# %%
df_bdate['year_bdate'] = pd.to_numeric(df_bdate['year_bdate'], errors= 'coerce')

# %%
df_bdate.dtypes
# Out:
# Unnamed: 0             int64
# id                     int64
# bdate                 object
# city                  object
# sex                   object
# first_name            object
# last_name             object
# can_access_closed       bool
# is_closed               bool
# university            object
# university_name       object
# faculty              float64
# faculty_name          object
# graduation           float64
# home_town             object
# education_form        object
# education_status      object
# deactivated           object
# sex_female              bool
# year_bdate             int64
# dtype: object

# %%
df_bdate['age'] = 2024 - df_bdate['year_bdate']

# %%
df_bdate
# Out:
#         Unnamed: 0          id       bdate             city  sex first_name  \
# 0                0        1257  19.10.1989           Sliema  NaN       Олег
# 1                1        1389  24.12.1986  Нижний Новгород  NaN       Иван
# 4                4        4913    5.2.1984  Санкт-Петербург  NaN     Марина
# 5                5        6559   13.1.1984          Барнаул  NaN      Федор
# 6                6        8612    1.4.1996           Phuket  NaN  Анастасия
# ...            ...         ...         ...              ...  ...        ...
# 248397      248397  1026426427   25.4.2001              NaN  NaN     Андрей
# 248398      248398  1026429726   27.8.1995              NaN  NaN      Захар
# 248399      248399  1029386637   19.2.2011              NaN  NaN      Олеся
# 248400      248400  1029757427    9.2.2006              NaN  NaN    Василий
# 248402      248402  1031810469   11.3.2003              NaN  NaN       Lina
#
#          last_name  can_access_closed  is_closed          university  ...  \
# 0         Уржумцев               True      False  хайер скул оф мемс  ...
# 1       Безбородый              False       True  хайер скул оф мемс  ...
# 4         Секачева              False       True  хайер скул оф мемс  ...
# 5         Клименко               True      False  хайер скул оф мемс  ...
# 6       Оболенская               True      False  хайер скул оф мемс  ...
# ...            ...                ...        ...                 ...  ...
# 248397    Барсуков              False       True     Подслушано ИТМО  ...
# 248398    Литвинов              False       True     Подслушано ИТМО  ...
# 248399      Работа               True      False     Подслушано ИТМО  ...
# 248400    Солдатов              False       True     Подслушано ИТМО  ...
# 248402        Milo               True      False     Подслушано ИТМО  ...
#
#        faculty                                       faculty_name graduation  \
# 0          NaN                                                NaN        NaN
# 1          NaN                                                NaN        NaN
# 4          NaN                                                NaN        NaN
# 5       3238.0                                     Филологический     2009.0
# 6        324.0  Компьютерных технологий и информатики (ФКТИ, Ф...     2004.0
# ...        ...                                                ...        ...
# 248397     NaN                                                NaN        NaN
# 248398     NaN                                                NaN        NaN
# 248399     NaN                                                NaN        NaN
# 248400     NaN                                                NaN        NaN
# 248402     0.0                                                NaN        0.0
#
#                         home_town   education_form        education_status  \
# 0                             NaN              NaN                     NaN
# 1                             NaN              NaN                     NaN
# 4                             NaN              NaN                     NaN
# 5       Барнаул - столица МИРА!!!  Очное отделение  Выпускник (специалист)
# 6                             NaN  Очное отделение    Выпускница (магистр)
# ...                           ...              ...                     ...
# 248397                        NaN              NaN                     NaN
# 248398                        NaN              NaN                     NaN
# 248399                        NaN              NaN                     NaN
# 248400                        NaN              NaN                     NaN
# 248402                        NaN              NaN                     NaN
#
#        deactivated sex_female  year_bdate  age
# 0              NaN      False        1989   35
# 1              NaN      False        1986   38
# 4              NaN      False        1984   40
# 5              NaN      False        1984   40
# 6              NaN      False        1996   28
# ...            ...        ...         ...  ...
# 248397      banned      False        2001   23
# 248398      banned      False        1995   29
# 248399      banned      False        2011   13
# 248400      banned      False        2006   18
# 248402         NaN      False        2003   21
#
# [93831 rows x 21 columns]

# %%
df_bdate['sex']
# Out:
# 0         NaN
# 1         NaN
# 4         NaN
# 5         NaN
# 6         NaN
#          ...
# 248397    NaN
# 248398    NaN
# 248399    NaN
# 248400    NaN
# 248402    NaN
# Name: sex, Length: 93831, dtype: object

# %%
df_bdate.groupby(
    by=['university'])[['age']].mean().sort_values(by='age', ascending=False)
# Out:
#                                    age
# university
# Подслушано ИТМО              29.730833
# Подслушано МГТУ им. Баумана  29.431502
# Подслушано ВШЭ               28.675658
# мемгу                        26.921421
# хайер скул оф мемс           26.841103

# %%
df_bdate.groupby(
    by=['sex'])[['age']].mean().sort_values(by='age', ascending=False)
# Out:
# Empty DataFrame
# Columns: [age]
# Index: []

# %% [markdown]
# ## Откуда аудитория - анализов городов

# %%
people_information_df['city'].unique()
# Out:
# array(['Sliema', 'Нижний Новгород', 'Санкт-Петербург', ..., 'Rabat',
#        'Ḑubay`ah', 'ЦИК СССР'], dtype=object)

# %%
df['city'].nunique()
# Out:
# 813

# %%
df_bdate.groupby(
    by=['city'])[['id']].count().sort_values(by='id', ascending=False).head(100)
# Out:
#                     id
# city
# Москва           37703
# Санкт-Петербург   7680
# Нижний Новгород   1014
# Пермь              699
# Казань             422
# ...                ...
# Баку                41
# Ногинск             41
# Тирасполь           41
# Донецк              41
# Praha               40
#
# [100 rows x 1 columns]
